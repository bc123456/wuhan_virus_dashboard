# %%
from lxml import html
import requests
import pandas as pd
import json
def fetch_stat():
    """
    Return a DataFrame that represent death, confirmed, investigating and reported numbers respectively.
    """
    statnames = ['Death', 'Confirmed', 'Investigating', 'Reported']
    
    page = requests.get('https://wars.vote4.hk/page-data/en/page-data.json')
    data = json.loads(page.content)
    stats = data['result']['data']['allDailyStats']['edges'][0]
    res = [stats['node']['death'], stats['node']['confirmed_case'], stats['node']['still_investigated'], stats['node']['fulfilling']]
    
    df = pd.DataFrame(data=[res], columns=statnames)
    
    return df

# %%
fetch_stat()
# Out:
#   Death Confirmed Investigating Reported
# 0     1        24           158     1100

# %%
def fetch_cases():
    """
    Returns a list of dictionary that contains the confirmed cases information.

    """
    page = requests.get('https://wars.vote4.hk/en/cases')
    tree = html.fromstring(page.content)

    boxes = tree.xpath('//*[@id="gatsby-focus-wrapper"]/div/main/div[2]/div[contains(@class, "CaseCard__WarsCaseContainer-zltyy4-0")]')

    res = []

    for box in boxes:
        s = box.xpath('./div[1]/div/text()')
        casenum = s[0]
        status = s[1]
        age_and_gender = box.xpath('./div[2]/div[1]/text()')[0]
        date = box.xpath('./div[3]/div[1]/div[1]/text()')[0]
        residence = box.xpath('./div[3]/div[1]/div[2]/text()')[0]
        hospital = box.xpath('./div[3]/div[1]/div[3]/text()')[0]
        desc = box.xpath('./div[4]/p/text()')[0]
        
        #get age from age_and_gender
        age = age_and_gender.replace('Age', '').replace('Male', '').replace('Female', '').strip()
        
        #get gender from age_and_gender
        gender = None
        if 'male' in age_and_gender.lower():
            gender = 'Male'
        elif 'female' in age_and_gender.lower():
            gender = 'Female'

        res.append({
            'casenum': str(casenum),
            'status': str(status),
            'age': int(age),
            'gender': str(gender),
            'date': str(date),
            'residence': str(residence),
            'hospital': str(hospital),
            'desc': str(desc)
        })

    return pd.DataFrame(res)

# %%
pd.DataFrame(fetch_cases())
# Out:
#             casenum        status  age gender        date  residence  \
# 0   #15 (Confirmed)  Hospitalised   72   Male  2020-02-02  Hong Kong
# 1   #14 (Confirmed)  Hospitalised   80   Male  2020-02-01  Hong Kong
# 2   #13 (Confirmed)  Hospitalised   39   Male  2020-01-31  Hong Kong
# 3   #12 (Confirmed)  Hospitalised   75   Male  2020-01-30  Hong Kong
# 4   #11 (Confirmed)  Hospitalised   37   Male  2020-01-30  Hong Kong
# 5   #10 (Confirmed)       Serious   72   Male  2020-01-29      Wuhan
# 6    #9 (Confirmed)  Hospitalised   73   Male  2020-01-29      Wuhan
# 7    #8 (Confirmed)  Hospitalised   64   Male  2020-01-26      Wuhan
# 8    #7 (Confirmed)      Critical   68   Male  2020-01-26  Hong Kong
# 9    #6 (Confirmed)  Hospitalised   47   Male  2020-01-26  Hong Kong
# 10   #5 (Confirmed)  Hospitalised   63   Male  2020-01-24      Wuhan
# 11   #4 (Confirmed)  Hospitalised   62   Male  2020-01-24      Wuhan
# 12   #3 (Confirmed)  Hospitalised   62   Male  2020-01-24      Wuhan
# 13   #2 (Confirmed)       Serious   56   Male  2020-01-23  Hong Kong
# 14   #1 (Confirmed)  Hospitalised   39   Male  2020-01-23      Wuhan
#
#                       hospital  \
# 0     Queen Elizabeth Hospital
# 1   Princess Margaret Hospital
# 2     Queen Elizabeth Hospital
# 3   Princess Margaret Hospital
# 4   Princess Margaret Hospital
# 5   Princess Margaret Hospital
# 6   Princess Margaret Hospital
# 7   Princess Margaret Hospital
# 8   Princess Margaret Hospital
# 9   Princess Margaret Hospital
# 10  Princess Margaret Hospital
# 11  Princess Margaret Hospital
# 12  Princess Margaret Hospital
# 13  Princess Margaret Hospital
# 14  Princess Margaret Hospital
#
#                                                  desc
# 0   The female patient is the mother of case no 13...
# 1   The patient lives in Luk Kwai House in Kwai Ch...
# 2   The male patient with long term illness lives ...
# 3   The 75 year-old patient lives in Cheung Hong E...
# 4   \nThe female patient is the daughter of a coup...
# 5   The male patient arrived in Hong Kong by plane...
# 6   The female patient arrived in Hong Kong by pla...
# 7   The 64 year-old male patient from Wuhan has lo...
# 8   The 68 year-old female patient lives in Fan Li...
# 9   The patient lied about his job of an accountan...
# 10  The 63 year-old male patient came from Wuhan w...
# 11  The 62 year-old female patient came from Wuhan...
# 12  The female patient took High Speed Rail from W...
# 13  The patient flew from Wuhan to ShenZhen, then ...
# 14  The patient travelled to Hong Kong by high spe...

# %%
with open(r'../data/CASES.pkl', 'wb') as f:
    pickle.dump(pd.DataFrame(fetch_cases()), f)

# %%
def fetch_awaiting_time():
    """
    Return a list of dictionary that contains the hospital awaiting time.

    """
    page = requests.get('https://wars.vote4.hk/en/ae-waiting-time')
    tree = html.fromstring(page.content)

    boxes = tree.xpath('//*[@id="gatsby-focus-wrapper"]/div/main/div[2]/div[contains(@class, "Card__StyledBox-sc-6m23vi-0 cNwpZn")]')

    res = []

    for box in boxes:
        district = box.xpath('./div[1]/div[1]/p[1]/text()')[0]
        hospital = box.xpath('./div[1]/div[1]/p[2]/text()')[0]
        time = box.xpath('./div[1]/h6/text()')[0]

        res.append({
             'district': str(district),
             'hospital': str(hospital),
             'time': str(time)
             })

    return pd.DataFrame(res)

# %%
fetch_awaiting_time()
# Out:
#          district                                  hospital    time
# 0    Sham Shui Po                    Caritas Medical Centre  < 1 hr
# 1        Mong Kok                        Kwong Wah Hospital  < 1 hr
# 2      Kwai Chung                Princess Margaret Hospital  < 1 hr
# 3       Yuen Long                           Pok Oi Hospital  < 1 hr
# 4       Tsuen Wan                         Yan Chai Hospital  < 1 hr
# 5      Tung Chung                     North Lantau Hospital  > 1 hr
# 6        Chai Wan  Pamela Youde Nethersole Eastern Hospital  > 1 hr
# 7     Cheung Chau                          St John Hospital  > 1 hr
# 8    Tin Shui Wai                     Tin Shui Wai Hospital  > 1 hr
# 9          Tai Po     Alice Ho Miu Ling Nethersole Hospital  > 2 hr
# 10    Sheung Shui                   North District Hospital  > 2 hr
# 11     Pok Fu Lam                       Queen Mary Hospital  > 2 hr
# 12       Wan Chai                        Ruttonjee Hospital  > 2 hr
# 13  Tseung Kwan O                    Tseung Kwan O Hospital  > 2 hr
# 14        Sha Tin                  Prince of Wales Hospital  > 3 hr
# 15     Yau Ma Tei                  Queen Elizabeth Hospital  > 3 hr
# 16       Tuen Mun                         Tuen Mun Hospital  > 3 hr
# 17      Kwun Tong                 United Christian Hospital  > 4 hr

# %%
with open(r'../data/AWAITING.pkl', 'wb') as f:
    pickle.dump(pd.DataFrame(fetch_awaiting_time()), f)

# %%
def fetch_stat():
    """
    Return a list of 4 numbers that represent death, confirmed, investigating and reported numbers respectively.

    """
    statnames = ['Death', 'Confirmed', 'Investigating', 'Reported']
    
    page = requests.get('https://wars.vote4.hk/en/')
    tree = html.fromstring(page.content)

    boxes = tree.xpath('//div[contains(@class, "pages__DailyStatsContainer-sc-6kvjaa-1")]/div')
    res = [int(box.xpath('./p[1]/text()')[0]) for box in boxes]
    
    df = pd.DataFrame(data=[res], columns=statnames)

    return df

# %%
fetch_stat()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a321038e460a> in <module>
# ----> 1 fetch_stat()
#
# <ipython-input-10-a30745e2566b> in fetch_stat()
#       6     statnames = ['Death', 'Confirmed', 'Investigating', 'Reported']
#       7
# ----> 8     page = requests.get('https://wars.vote4.hk/en/')
#       9     tree = html.fromstring(page.content)
#      10
#
# NameError: name 'requests' is not defined

# %%
import pickle
with open(r'../data/STATS.pkl', 'wb') as f:
    pickle.dump(fetch_stat(), f)

# %%
import pytz
import datetime

# %%
fmt = '%Y-%m-%d %H:%M:%S %Z%z'
hong_kong_time = pytz.timezone('US/Eastern')
loc_dt = hong_kong_time.localize(datetime.datetime.now())
loc_dt.strftime(fmt)
# Out:
# '2020-02-04 13:53:30 EST-0500'

# %%
datetime.datetime.now(hong_kong_time)
# Out:
# datetime.datetime(2020, 2, 4, 0, 53, 56, 858119, tzinfo=<DstTzInfo 'US/Eastern' EST-1 day, 19:00:00 STD>)

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2020, 2, 4, 13, 47, 27, 151291)

# %%
import plotly.express as px
px.colors.sequential.Bluered[::-1]
# Out:
# ['rgb(255,0,0)', 'rgb(0,0,255)']

# %%
fetch_highrisk()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a90adaed75bf> in <module>
# ----> 1 fetch_highrisk()
#
# <ipython-input-12-96ec8de9b562> in fetch_highrisk()
#       4
#       5     """
# ----> 6     page = requests.get('https://wars.vote4.hk/page-data/en/high-risk/page-data.json')
#       7     data = json.loads(page.content)
#       8     cases = data['result']['data']['allWarsCaseLocation']['edges']
#
# NameError: name 'requests' is not defined
