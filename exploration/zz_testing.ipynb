# %%
from lxml import html
import requests

def fetch_highrisk():
    """b
    Returns a list of dictionary that contains the high risk area information.

    """
    page = requests.get('https://wars.vote4.hk/en/high-risk')
    tree = html.fromstring(page.content)

    boxes = tree.xpath('//*[@id="gatsby-focus-wrapper"]/div/main/div[2]/div[contains(@class, "Card__StyledBox-sc-6m23vi-0 cNwpZn")]')

    res = []

    for box in boxes:
        district = box.xpath('./div[1]/div[1]/div[1]/div/span[contains(@class, "MuiTypography-body2")]/text()')
        address = box.xpath('./div[1]/div[1]/div[1]/div/span[contains(@class, "MuiTypography-h6")]/text()')
        msg = box.xpath('./div[1]/span/text()')

        res.append({'district': str(district[0]), 'address': str(address[0]), 'msg': str(msg[0])})

    return res

# %%
fetch_highrisk()
# Out:
# [{'district': 'Jordan',
#   'address': 'West Kowloon Station',
#   'msg': 'Multiple confirmed cases of novel coronavirus infection came into Hong Kong via High Speed Rail'},
#  {'district': 'Kwai Chung',
#   'address': 'Luk Kwai House Kwai Chung Estate',
#   'msg': 'The flat where a confirmed novel coronavirus patient lives'},
#  {'district': 'Sheung Shui',
#   'address': 'Lo Wu Customs Checkpoint',
#   'msg': 'A confirmed case went to Mainland via this customs checkpoint on 10 January.'},
#  {'district': 'Kowloon City',
#   'address': 'Kai Tak Cruise Terminal',
#   'msg': 'A confirmed case arrived at this cruise terminal via cruise on 10 January.'},
#  {'district': '-',
#   'address': '"Enhanted Princess" Cruise',
#   'msg': 'A confirmed case traveled on this cruise on 20 - 25 January.'},
#  {'district': 'Hung Hom',
#   'address': 'Block 1, Site 11, Whampoa Garden',
#   'msg': 'A confirmed case of novel coronavirus, the patient has been to Wuhan in January 21 to 23; their families has now been relocated to the quarantine camp'},
#  {'district': 'Tsing Yi',
#   'address': 'Wah Cheung House, Ching Wah Court',
#   'msg': 'A resident shows symptoms after visiting Wuhan'},
#  {'district': 'Jordan',
#   'address': 'Tower 2, The Coronation',
#   'msg': 'The flat where a confirmed novel coronavirus couple and their daughter lives'},
#  {'district': 'Tsing Yi',
#   'address': 'Cheung Hong Estate, Hong Mei House',
#   'msg': 'A confirmed case of novel coronavirus has been to mainland and Macau before'},
#  {'district': 'Central',
#   'address': 'Four Seasons Hotel Hong Kong',
#   'msg': 'A confirmed case stayed in this Hotel for a few hours'},
#  {'district': 'Jordan',
#   'address': 'W Hong Kong',
#   'msg': 'Two confirmed cases stayed in this hotel'},
#  {'district': 'Jordan',
#   'address': 'The Ritz-Carlton',
#   'msg': 'A confirmed case of novel coronavirus infection stayed in the hotel for a few hours attempted to check in but failed'},
#  {'district': 'Tseung Kwan O',
#   'address': 'Block 2, Tseung Kwan O Plaza',
#   'msg': 'A confirmed case stayed in this residence before admission to hospital'},
#  {'district': 'North Point',
#   'address': 'Universal Towers',
#   'msg': 'The flat where a confirmed novel coronavirus patient lives'},
#  {'district': 'Tuen Mun',
#   'address': 'South Hillcrest',
#   'msg': 'Residence of one of the confirmed cases and her family members'},
#  {'district': 'Ma On Shan',
#   'address': 'Tower 1, Lake Silver',
#   'msg': 'Two confirmed cases stayed in this residence before admission to hospital'},
#  {'district': 'Tsim Sha Tsui',
#   'address': 'Empire Hotel Kowloon, Tsim Sha Tsui',
#   'msg': 'Family members in close contact with a confirmed case of novel coronavirus infection stayed in the hotel'},
#  {'district': 'Sheung Wan',
#   'address': 'Floor 23, Li Po Chun Chambers',
#   'msg': "The office where a confirmed novel coronavirus couple's daughter works"},
#  {'district': 'Ma On Shan',
#   'address': '26/F, Tower 1A, Oceanaire',
#   'msg': 'Residence of one of the confirmed cases and his family members'},
#  {'district': 'Sha Tin',
#   'address': 'Alva Hotel by Royal',
#   'msg': 'A confirmed case stayed in the hotel when having high fever'}]

# %%
def fetch_cases():
    """
    Returns a list of dictionary that contains the confirmed cases information.

    """
    page = requests.get('https://wars.vote4.hk/en/cases')
    tree = html.fromstring(page.content)

    boxes = tree.xpath('//*[@id="gatsby-focus-wrapper"]/div/main/div[2]/div[contains(@class, "CaseCard__WarsCaseContainer-zltyy4-0")]')

    res = []

    for box in boxes:
        s = box.xpath('./div[1]/div/text()')
        casenum = s[0]
        status = s[1]
        age = box.xpath('./div[2]/div[1]/text()')[0]
        date = box.xpath('./div[3]/div[1]/div[1]/text()')[0]
        residence = box.xpath('./div[3]/div[1]/div[2]/text()')[0]
        hospital = box.xpath('./div[3]/div[1]/div[3]/text()')[0]
        desc = box.xpath('./div[4]/p/text()')[0]

        res.append({
             'casenum': str(casenum),
             'status': str(status),
             'age': str(age),
             'date': str(date),
             'residence': str(residence),
             'hospital': str(hospital),
             'desc': str(desc)
        })

    return res

# %%
fetch_cases()
# Out:
# [{'casenum': '#15 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 72 Female',
#   'date': '2020-02-02',
#   'residence': 'Hong Kong',
#   'hospital': 'Queen Elizabeth Hospital',
#   'desc': 'The female patient is the mother of case no 13. She was transferred to quarantine area for treatment on 31 January after case 13 is confirmed. She showed symptoms in the quaratine area afterwards.'},
#  {'casenum': '#14 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 80 Male',
#   'date': '2020-02-01',
#   'residence': 'Hong Kong',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The patient lives in Luk Kwai House in Kwai Chung. He spent a few hours in Mainland via the Lo Wu checkpoint on 10 January. He flew to Tokyo on 17 January and joined a cruise from Yokohama with his two daughter on January 20. They arrived at the Kai Tak Cruise Terminal on January 25. He started coughing on 19 January, and got fever on 30 January. He sought treatment on 30 January in Caritas Medical Centre.'},
#  {'casenum': '#13 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 39 Male',
#   'date': '2020-01-31',
#   'residence': 'Hong Kong',
#   'hospital': 'Queen Elizabeth Hospital',
#   'desc': 'The male patient with long term illness lives in Block 1, Phase 11 Bauhinia Mansions Whampoa Garden. He has been to Wuhan during 21 Jan by High Speed Rail and returned to Hong Kong via Cheung Sha South Station by High Speed Rail. He had muscle pain on 29 January and fever on 31 January. He is submitted to Elizabeth hospital for quarantine.'},
#  {'casenum': '#12 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 75 Male',
#   'date': '2020-01-30',
#   'residence': 'Hong Kong',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The 75 year-old patient lives in Cheung Hong Estate Hong Mei House. He had coughing and breathing problem on 22 Jan, and was admitted to Margaret Hospital on 24 Jan. He was confirmed as carrier of coronavirus and submitted to quarantine on 30 Jan. There are reports mentioning that the patient stayed in General patient room for 7 days before transferring to Hong Kong Infectious Disease Centre Princess .'},
#  {'casenum': '#11 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 37 Female',
#   'date': '2020-01-30',
#   'residence': 'Hong Kong',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': '\nThe female patient is the daughter of a couple (case 9 and 10) whom are confirmed with the diagnosis of WARS few days ago. It maybe the first case of person to person infection. She lived in The Coronation, Yau Ma Tei. She had coughing on 28 Jan and was submitted to quarantine in Elizabeth Hospital on 30 Jan. She had a short stay in the resident of Yau Ma Tei.'},
#  {'casenum': '#10 (Confirmed)',
#   'status': 'Serious',
#   'age': 'Age 72 Male',
#   'date': '2020-01-29',
#   'residence': 'Wuhan',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The male patient arrived in Hong Kong by plane on 22 Jan, checked in at W hotel and the Four Seasons hotel a few days later. He stayed a few hours in the Four Seasons and sent to the hospital due to sickness.'},
#  {'casenum': '#9 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 73 Female',
#   'date': '2020-01-29',
#   'residence': 'Wuhan',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': "The female patient arrived in Hong Kong by plane on 22 Jan, checked in at W hotel and the Four Seasons hotel a few days later. She stayed at the Four Seasons hotel for a few hours. Unfortunately, she wasn't cooperative and thus, the schedule of hers could not be confirmed."},
#  {'casenum': '#8 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 64 Male',
#   'date': '2020-01-26',
#   'residence': 'Wuhan',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The 64 year-old male patient from Wuhan has long term illness. He went to Hong Kong via North ShenZhen by High Speed Rail G1013 with his spouse (Case 3) on 19 Jan, and arriving Hong Kong West Kowloon station by High Rail G6543. The patient and his spouse visited his daughter and son-in-law in South Hilcrest, Tuen Mun. He was transferred to quarantine area of Lady MacLehose Holiday Village for further examination. He had fever on 26 Jan and was transferred to Tuen Mun Hospital the same day for quarantine and medical treatment.'},
#  {'casenum': '#7 (Confirmed)',
#   'status': 'Critical',
#   'age': 'Age 68 Female',
#   'date': '2020-01-26',
#   'residence': 'Hong Kong',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The 68 year-old female patient lives in Fan Ling. She visited Wuhan in January and was tested positive for Influenza A virus with clear chest X-ray in ShenZhen hospital. After being discharged on 22 Jan, she arrived in Hong Kong on 25 Jan and was transferred to North District Hospital upon detection of high fever at the Hong Kong customs.'},
#  {'casenum': '#6 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 47 Male',
#   'date': '2020-01-26',
#   'residence': 'Hong Kong',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The patient lied about his job of an accountant but indeed he works as a cashier in a market at Wuhan Wuchang Baishazhou. He has reported to Ruttonjee Hospital about being bitten by a dog and received rabies vaccination on 23 Jan. He was not having fever on 23 Jan. The patient recorded with high body temperature on 24 Jan and was hospitalised on 25 Jan.'},
#  {'casenum': '#5 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 63 Male',
#   'date': '2020-01-24',
#   'residence': 'Wuhan',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The 63 year-old male patient came from Wuhan with her spouse (case 4) to visit their daughter at Ma On Shan (Lake Silver). The couple are not Hong Kong residient. They tried to escape from the hospital when they learnt about the expensive fees for non-Hong Kong residents. The couple were finally caught by police and returned to the hospital for quarantine.'},
#  {'casenum': '#4 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 62 Female',
#   'date': '2020-01-24',
#   'residence': 'Wuhan',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The 62 year-old female patient came from Wuhan with her spouse (case 5) to visit their daughter at Ma On Shan (Lake Silver). Since the couple are not Hong Kong residient, they tried to escape from the hospital when they learnt about the expensive fees for non-Hong Kong residents. The couple were finally caught by police and returned to the hospital for quarantine area again.'},
#  {'casenum': '#3 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 62 Female',
#   'date': '2020-01-24',
#   'residence': 'Wuhan',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The female patient took High Speed Rail from Wuhan to Hong Kong on 19 Jan and resided in South Hillcrest (Tuen Mun). Symptoms appeared on 20 Jan, while she went to Tuen Mun Hospital for emergency medical service on 23 Jan. During her wait for medical treatment, she was wrongly placed in trauma ward due to full occupancy of negative pressure isolation rooms. She visited the wet market and hospital during her stay in Wuhan within the incubation period but denied history of close contact with wild animals.'},
#  {'casenum': '#2 (Confirmed)',
#   'status': 'Serious',
#   'age': 'Age 56 Male',
#   'date': '2020-01-23',
#   'residence': 'Hong Kong',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The patient flew from Wuhan to ShenZhen, then took East rail line and Ma on shan line from Lo wu to Ma On Shan. He requested medical service at Prince of Wales hospital due to fever then checked in at Alva Hotel (Shatin). Oxygen supply and medical treatment are required.'},
#  {'casenum': '#1 (Confirmed)',
#   'status': 'Hospitalised',
#   'age': 'Age 39 Male',
#   'date': '2020-01-23',
#   'residence': 'Wuhan',
#   'hospital': 'Princess Margaret Hospital',
#   'desc': 'The patient travelled to Hong Kong by high speed rail on 21 Jan, was sent to the hospital immediately as spotted fever in West Kowloon station. The other four family members stayed in Empire Hotel Kowloon-Tsim Sha Tsui, took the flight on 22 Jan to Manila, Philippines.'}]

# %%
def fetch_awaiting_time():
    """
    Return a list of dictionary that contains the hospital awaiting time.

    """
    page = requests.get('https://wars.vote4.hk/en/ae-waiting-time')
    tree = html.fromstring(page.content)

    boxes = tree.xpath('//*[@id="gatsby-focus-wrapper"]/div/main/div[2]/div[contains(@class, "Card__StyledBox-sc-6m23vi-0 cNwpZn")]')

    res = []

    for box in boxes:
        district = box.xpath('./div[1]/div[1]/p[1]/text()')[0]
        hospital = box.xpath('./div[1]/div[1]/p[2]/text()')[0]
        time = box.xpath('./div[1]/h6/text()')[0]

        res.append({
             'district': str(district),
             'hospital': str(hospital),
             'time': str(time)
             })

    return res

# %%
fetch_awaiting_time()
# Out:
# [{'district': 'Mong Kok', 'hospital': 'Kwong Wah Hospital', 'time': '< 1 hr'},
#  {'district': 'Kwai Chung',
#   'hospital': 'Princess Margaret Hospital',
#   'time': '< 1 hr'},
#  {'district': 'Yuen Long', 'hospital': 'Pok Oi Hospital', 'time': '< 1 hr'},
#  {'district': 'Sha Tin',
#   'hospital': 'Prince of Wales Hospital',
#   'time': '< 1 hr'},
#  {'district': 'Pok Fu Lam',
#   'hospital': 'Queen Mary Hospital',
#   'time': '< 1 hr'},
#  {'district': 'Cheung Chau', 'hospital': 'St John Hospital', 'time': '< 1 hr'},
#  {'district': 'Tin Shui Wai',
#   'hospital': 'Tin Shui Wai Hospital',
#   'time': '< 1 hr'},
#  {'district': 'Tsuen Wan', 'hospital': 'Yan Chai Hospital', 'time': '< 1 hr'},
#  {'district': 'Sham Shui Po',
#   'hospital': 'Caritas Medical Centre',
#   'time': '> 1 hr'},
#  {'district': 'Tung Chung',
#   'hospital': 'North Lantau Hospital',
#   'time': '> 1 hr'},
#  {'district': 'Yau Ma Tei',
#   'hospital': 'Queen Elizabeth Hospital',
#   'time': '> 1 hr'},
#  {'district': 'Tseung Kwan O',
#   'hospital': 'Tseung Kwan O Hospital',
#   'time': '> 1 hr'},
#  {'district': 'Tuen Mun', 'hospital': 'Tuen Mun Hospital', 'time': '> 1 hr'},
#  {'district': 'Sheung Shui',
#   'hospital': 'North District Hospital',
#   'time': '> 2 hr'},
#  {'district': 'Chai Wan',
#   'hospital': 'Pamela Youde Nethersole Eastern Hospital',
#   'time': '> 2 hr'},
#  {'district': 'Wan Chai', 'hospital': 'Ruttonjee Hospital', 'time': '> 2 hr'},
#  {'district': 'Tai Po',
#   'hospital': 'Alice Ho Miu Ling Nethersole Hospital',
#   'time': '> 3 hr'},
#  {'district': 'Kwun Tong',
#   'hospital': 'United Christian Hospital',
#   'time': '> 3 hr'}]

# %%
def fetch_stat():
    """
    Return a list of 4 numbers that represent death, confirmed, investigating and reported numbers respectively.

    """
    page = requests.get('https://wars.vote4.hk/en/')
    tree = html.fromstring(page.content)

    boxes = tree.xpath('//div[contains(@class, "pages__DailyStatsContainer-sc-6kvjaa-1")]/div')
    res = [int(box.xpath('./p[1]/text()')[0]) for box in boxes]

    return res

# %%
fetch_stat()
# Out:
# [0, 15, 168, 882]
