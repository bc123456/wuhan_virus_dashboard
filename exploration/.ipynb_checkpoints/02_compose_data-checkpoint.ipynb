# %%
import pandas as pd
import pickle
import numpy as np
import sys
import requests
import json
sys.path.insert(1, '../src')

# %% [markdown]
# ## Basic Statistics

# %%
with open(r'../data/STATS.pkl', 'rb') as f:
    stats_df = pickle.load(f)

# %%
from webscraper import fetch_stat
stats_df = fetch_stat()

# %%
stats_df
# Out:
#   Death Confirmed Investigating Reported
# 0     1        24           158     1100

# %%
def fetch_stat():
    """
    Return a DataFrame that represent death, confirmed, investigating and reported numbers respectively.
    
    There are two elements in the json that contain the required value: 
    "allBotWarsLatestFigures" and "allWarsLatestFiguresOverride".
    
    The values in allBotWarsLatestFigures are the record in history for every day.
    The values in allWarsLatestFiguresOverride are the live values.
    Whenenver an attribute in allWarsLatestFiguresOverride is not an empty string,
    it overrides the values in allBotWarsLatestFigures.
    
    """
    statnames = ['Death', 'Confirmed', 'Investigating', 'Reported']
    
    page = requests.get('https://wars.vote4.hk/page-data/en/page-data.json')
    data = json.loads(page.content)
    print(json.dumps(data['result']['data'], indent=4, sort_keys=True))
    stats_yesterday = data['result']['data']['allBotWarsLatestFigures']['edges'][0]
    stats_live = data['result']['data']['allWarsLatestFiguresOverride']['edges'][0]
    
    res = {}
    
    for attr in ['death', 'confirmed', 'investigating', 'reported', 'discharged', 'ruled_out']:
        if stats_live['node'][attr] != "":
            res[attr] = stats_live['node'][attr]
        else:
            res[attr] = stats_yesterday['node'][attr]
    
    df = pd.DataFrame(data=res, index=[0])
    
    return df

# %%
fetch_stat()
# Out:
# {
#     "allBotWarsLatestFigures": {
#         "edges": [
#             {
#                 "node": {
#                     "confirmed": "36",
#                     "date": "2020-02-09",
#                     "death": "1",
#                     "discharged": "0",
#                     "investigating": "129",
#                     "reported": "1231",
#                     "ruled_out": "1066",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "26",
#                     "date": "2020-02-08",
#                     "death": "1",
#                     "discharged": "0",
#                     "investigating": "141",
#                     "reported": "1202",
#                     "ruled_out": "1035",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "26",
#                     "date": "2020-02-07",
#                     "death": "1",
#                     "discharged": "0",
#                     "investigating": "158",
#                     "reported": "1158",
#                     "ruled_out": "975",
#                     "time": "23:59"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "24",
#                     "date": "2020-02-06",
#                     "death": "1",
#                     "discharged": "0",
#                     "investigating": "158",
#                     "reported": "1100",
#                     "ruled_out": "920",
#                     "time": "23:59"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "21",
#                     "date": "2020-02-05",
#                     "death": "1",
#                     "discharged": "0",
#                     "investigating": "154",
#                     "reported": "1043",
#                     "ruled_out": "868",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "18",
#                     "date": "2020-02-04",
#                     "death": "1",
#                     "discharged": "0",
#                     "investigating": "157",
#                     "reported": "982",
#                     "ruled_out": "808",
#                     "time": "23:59"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "15",
#                     "date": "2020-02-03",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "159",
#                     "reported": "918",
#                     "ruled_out": "744",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "15",
#                     "date": "2020-02-02",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "168",
#                     "reported": "882",
#                     "ruled_out": "699",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "14",
#                     "date": "2020-02-01",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "188",
#                     "reported": "835",
#                     "ruled_out": "634",
#                     "time": "23:59"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "13",
#                     "date": "2020-01-31",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "203",
#                     "reported": "766",
#                     "ruled_out": "550",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "12",
#                     "date": "2020-01-30",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "191",
#                     "reported": "680",
#                     "ruled_out": "478",
#                     "time": "23:59"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "10",
#                     "date": "2020-01-29",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "159",
#                     "reported": "585",
#                     "ruled_out": "416",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "8",
#                     "date": "2020-01-28",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "189",
#                     "reported": "529",
#                     "ruled_out": "332",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "8",
#                     "date": "2020-01-27",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "167",
#                     "reported": "451",
#                     "ruled_out": "276",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "8",
#                     "date": "2020-01-26",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "155",
#                     "reported": "382",
#                     "ruled_out": "219",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "5",
#                     "date": "2020-01-25",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "137",
#                     "reported": "305",
#                     "ruled_out": "163",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "5",
#                     "date": "2020-01-24",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "117",
#                     "reported": "244",
#                     "ruled_out": "122",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "2",
#                     "date": "2020-01-23",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "65",
#                     "reported": "176",
#                     "ruled_out": "109",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-22",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "38",
#                     "reported": "135",
#                     "ruled_out": "97",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-21",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "30",
#                     "reported": "118",
#                     "ruled_out": "88",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-20",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "25",
#                     "reported": "106",
#                     "ruled_out": "81",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-19",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "19",
#                     "reported": "99",
#                     "ruled_out": "80",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-18",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "14",
#                     "reported": "90",
#                     "ruled_out": "76",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-17",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "6",
#                     "reported": "81",
#                     "ruled_out": "75",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-16",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "7",
#                     "reported": "78",
#                     "ruled_out": "71",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-15",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "10",
#                     "reported": "76",
#                     "ruled_out": "66",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-14",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "11",
#                     "reported": "71",
#                     "ruled_out": "60",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-13",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "12",
#                     "reported": "68",
#                     "ruled_out": "56",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-12",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "16",
#                     "reported": "67",
#                     "ruled_out": "51",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-11",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "15",
#                     "reported": "61",
#                     "ruled_out": "46",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-10",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "23",
#                     "reported": "54",
#                     "ruled_out": "31",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-09",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "23",
#                     "reported": "48",
#                     "ruled_out": "25",
#                     "time": "12:00"
#                 }
#             },
#             {
#                 "node": {
#                     "confirmed": "0",
#                     "date": "2020-01-08",
#                     "death": "0",
#                     "discharged": "0",
#                     "investigating": "17",
#                     "reported": "38",
#                     "ruled_out": "21",
#                     "time": "12:00"
#                 }
#             }
#         ]
#     },
#     "allImmdAirport": {
#         "edges": [
#             {
#                 "node": {
#                     "arrival_hong_kong": 22077,
#                     "arrival_mainland": 913,
#                     "arrival_other": 2591,
#                     "arrival_total": 25581,
#                     "date": "2020-02-09",
#                     "departure_hong_kong": 17782,
#                     "departure_mainland": 17782,
#                     "departure_other": 3200,
#                     "departure_total": 21953,
#                     "location": "Airport"
#                 }
#             },
#             {
#                 "node": {
#                     "arrival_hong_kong": 17956,
#                     "arrival_mainland": 943,
#                     "arrival_other": 3070,
#                     "arrival_total": 21969,
#                     "date": "2020-02-08",
#                     "departure_hong_kong": 20163,
#                     "departure_mainland": 20163,
#                     "departure_other": 3253,
#                     "departure_total": 24543,
#                     "location": "Airport"
#                 }
#             }
#         ]
#     },
#     "allImmdHongKongZhuhaiMacaoBridge": {
#         "edges": [
#             {
#                 "node": {
#                     "arrival_hong_kong": 710,
#                     "arrival_mainland": 7,
#                     "arrival_other": 493,
#                     "arrival_total": 1210,
#                     "date": "2020-02-09",
#                     "departure_hong_kong": 1185,
#                     "departure_mainland": 1185,
#                     "departure_other": 524,
#                     "departure_total": 1876,
#                     "location": "Hong Kong-Zhuhai-Macao Bridge"
#                 }
#             },
#             {
#                 "node": {
#                     "arrival_hong_kong": 659,
#                     "arrival_mainland": 9,
#                     "arrival_other": 508,
#                     "arrival_total": 1176,
#                     "date": "2020-02-08",
#                     "departure_hong_kong": 750,
#                     "departure_mainland": 750,
#                     "departure_other": 442,
#                     "departure_total": 1355,
#                     "location": "Hong Kong-Zhuhai-Macao Bridge"
#                 }
#             }
#         ]
#     },
#     "allImmdShenzhenBay": {
#         "edges": [
#             {
#                 "node": {
#                     "arrival_hong_kong": 314,
#                     "arrival_mainland": 36,
#                     "arrival_other": 3,
#                     "arrival_total": 353,
#                     "date": "2020-02-09",
#                     "departure_hong_kong": 1802,
#                     "departure_mainland": 1802,
#                     "departure_other": 573,
#                     "departure_total": 3678,
#                     "location": "Shenzhen Bay"
#                 }
#             },
#             {
#                 "node": {
#                     "arrival_hong_kong": 208,
#                     "arrival_mainland": 43,
#                     "arrival_other": 3,
#                     "arrival_total": 254,
#                     "date": "2020-02-08",
#                     "departure_hong_kong": 1291,
#                     "departure_mainland": 1291,
#                     "departure_other": 549,
#                     "departure_total": 3191,
#                     "location": "Shenzhen Bay"
#                 }
#             }
#         ]
#     },
#     "allImmdTotal": {
#         "edges": [
#             {
#                 "node": {
#                     "arrival_hong_kong": 24939,
#                     "arrival_mainland": 956,
#                     "arrival_other": 3120,
#                     "arrival_total": 29015,
#                     "date": "2020-02-09",
#                     "departure_hong_kong": 20769,
#                     "departure_mainland": 20769,
#                     "departure_other": 4297,
#                     "departure_total": 27507,
#                     "location": "Total"
#                 }
#             },
#             {
#                 "node": {
#                     "arrival_hong_kong": 18823,
#                     "arrival_mainland": 995,
#                     "arrival_other": 3581,
#                     "arrival_total": 23399,
#                     "date": "2020-02-08",
#                     "departure_hong_kong": 22204,
#                     "departure_mainland": 22204,
#                     "departure_other": 4244,
#                     "departure_total": 29089,
#                     "location": "Total"
#                 }
#             }
#         ]
#     },
#     "allWarsCase": {
#         "edges": [
#             {
#                 "node": {
#                     "age": "69",
#                     "case_no": "37",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_unknown_source",
#                     "confirmation_date": "2020-02-10",
#                     "detail_en": "Patient stays in Intensive Care Unit (ICU) in Pamela Youde Nethersole Hospital.  He has no travel history.",
#                     "detail_zh": "\u60a3\u8005\u73fe\u6642\u7559\u91ab\u6771\u5340\u91ab\u9662\u6df1\u5207\u6cbb\u7642\u90e8\u3002\u4ed6\u6700\u8fd1\u6c92\u6709\u5916\u904a\u7d00\u9304\u3002",
#                     "gender": "M",
#                     "hospital_en": "Pamela Youde Nethersole Eastern Hospital",
#                     "hospital_zh": "\u6771\u5340\u5c24\u5fb7\u592b\u4eba\u90a3\u6253\u7d20\u91ab\u9662",
#                     "onset_date": "",
#                     "source_url": "https://hk.appledaily.com/local/20200210/BCZLE5EYY4BPLHD4AYCOYSB22Y/",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             },
#             {
#                 "node": {
#                     "age": "24",
#                     "case_no": "27",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_possibly",
#                     "confirmation_date": "2020-02-09",
#                     "detail_en": "The patient lives on Lockhart Road, Wanchai. On Jan 26, the patient had a get-together with family members/relatives, totaling 19 people. The group met in a party room in Kwun Tong where they had barbecue and hotpot on a balcony. Two of those present at the gathering were from Guangdong Province, China and left Hong Kong in late January.  The patient and some of his family members have shown symptoms of pneumonia. He is currently receiving treatment at Ruttonjee Hospital. He had not travelled outside Hong Kong in the last 14 days before admission.",
#                     "detail_zh": "\u60a3\u8005\u4f4f\u5728\u7063\u4ed4\u99f1\u514b\u9053\u3002\u5728 1 \u6708 26 \u65e5\u8fb2\u66c6\u5e74\u521d\u4e8c\u66fe\u8207\u591a\u540d\u89aa\u53cb\uff08\u5408\u5171 19 \u4eba\uff09\u5728\u89c0\u5858\u6c38\u8208\u5de5\u696d\u5927\u5ec8\u4e00\u9593\u6d3e\u5c0d\u623f\u9593\u53c3\u8207\u805a\u6703\uff0c\u6709\u95dc\u5730\u9ede\u6709\u4e00\u500b\u9732\u53f0\uff0c\u4ed6\u5011\u5728\u9732\u53f0\u71d2\u70e4\u53ca\u6253\u908a\u7210\u3002\u5728\u5834\u5305\u62ec 2 \u540d\u5f9e\u4e2d\u570b\u5ee3\u6771\u7701\u4f86\u6e2f\u7684\u89aa\u53cb\uff0c\u5169\u4eba\u5747\u5728 1 \u6708\u5e95\u96e2\u958b\u9999\u6e2f\u3002\u53ca\u5f8c\u7537\u60a3\u8005\u8207\u5176\u4ed6\u5bb6\u4eba\u5747\u6709\u80ba\u708e\u75c7\u72c0\u3002\u7537\u60a3\u8005\u73fe\u6642\u5728\u5f8b\u6566\u6cbb\u91ab\u9662\u63a5\u53d7\u6cbb\u7642\u3002\u5728\u904e\u53bb 14 \u65e5\u6c92\u6709\u5916\u904a\u7d00\u9304\u3002",
#                     "gender": "M",
#                     "hospital_en": "Ruttonjee Hospital",
#                     "hospital_zh": "\u5f8b\u6566\u6cbb\u91ab\u9662",
#                     "onset_date": "2020-01-30",
#                     "source_url": "https://news.rthk.hk/rthk/ch/component/k2/1507560-20200209.htm",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             },
#             {
#                 "node": {
#                     "age": "70",
#                     "case_no": "28",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_unknown_source",
#                     "confirmation_date": "2020-02-09",
#                     "detail_en": "The patient lives in Ngau Chi Wan and has chronic illness(es). He sought treatment for coughs and chills on Jan 30. He was admitted to United Christian Hospital for quarantine on Feb 8. He claimed that he had not travelled outside Hong Kong during the incubation period.",
#                     "detail_zh": "\u60a3\u8005\u4f4f\u5728\u725b\u6c60\u7063\uff0c\u672c\u8eab\u6709\u6162\u6027\u75be\u75c5\uff0c1 \u6708 30 \u65e5\u54b3\u55fd\u3001\u767c\u51b7\u6c42\u91ab\uff0c2 \u6708 8 \u65e5\u5728\u806f\u5408\u91ab\u9662\u9694\u96e2\uff0c\u5831\u7a31\u6f5b\u4f0f\u671f\u9593\u6c92\u6709\u5916\u904a\u3002",
#                     "gender": "M",
#                     "hospital_en": "United Christian Hospital",
#                     "hospital_zh": "\u57fa\u7763\u6559\u806f\u5408\u91ab\u9662",
#                     "onset_date": "2020-01-30",
#                     "source_url": "https://news.rthk.hk/rthk/ch/component/k2/1507560-20200209.htm",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             },
#             {
#                 "node": {
#                     "age": "91",
#                     "case_no": "29",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_possibly_close_contact",
#                     "confirmation_date": "2020-02-09",
#                     "detail_en": "The patient has chronic illness(es). She is the grandmother of case no. 27 and also lives on Lockhart Road, Wanchai. She attended the same get-together on Jan 26 with the other 18 family members/relatives. She had not travelled outside Hong Kong in the last 14 days before admission. She was once admitted to the Medical Ward of Pamela Youde Nethersole Eastern Hospital.",
#                     "detail_zh": "\u60a3\u8005\u672c\u8eab\u60a3\u6709\u6162\u6027\u75c5\u3002\u5979\u662f\u7b2c 27 \u5b97\u78ba\u8a3a\u500b\u6848\u7684\u5916\u5a46\uff0c\u5747\u4f4f\u5728\u7063\u4ed4\u99f1\u514b\u9053\u30021 \u6708 26 \u65e5\u5e74\u521d\u4e8c\u6642\u4e00\u540c\u53c3\u8207\u89aa\u53cb\u805a\u6703\u3002\u5728\u904e\u53bb 14 \u65e5\u6c92\u6709\u5916\u904a\u7d00\u9304\u3002\u5973\u60a3\u8005\u66fe\u5165\u4f4f\u6771\u5340\u5c24\u5fb7\u91ab\u9662\u5167\u79d1\u75c5\u623f\u3002",
#                     "gender": "F",
#                     "hospital_en": "Pamela Youde Nethersole Eastern Hospital",
#                     "hospital_zh": "\u6771\u5340\u5c24\u5fb7\u592b\u4eba\u90a3\u6253\u7d20\u91ab\u9662",
#                     "onset_date": "2020-02-01",
#                     "source_url": "https://news.rthk.hk/rthk/ch/component/k2/1507560-20200209.htm",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             },
#             {
#                 "node": {
#                     "age": "68",
#                     "case_no": "30",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_possibly_close_contact",
#                     "confirmation_date": "2020-02-09",
#                     "detail_en": "Father of patient 27",
#                     "detail_zh": "\u7b2c 27 \u5b97\u7537\u60a3\u8005\u7684\u7236\u89aa",
#                     "gender": "M",
#                     "hospital_en": "Ruttonjee Hospital",
#                     "hospital_zh": "\u5f8b\u6566\u6cbb\u91ab\u9662",
#                     "onset_date": "2020-01-29",
#                     "source_url": "https://hk.news.appledaily.com/local/20200210/BCZLE5EYY4BPLHD4AYCOYSB22Y/?utm_campaign=hkad_social_hk.nextmedia&utm_medium=social&utm_source=telegram",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             },
#             {
#                 "node": {
#                     "age": "57",
#                     "case_no": "31",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_possibly_close_contact",
#                     "confirmation_date": "2020-02-09",
#                     "detail_en": "Mother of patient 27",
#                     "detail_zh": "\u7b2c 27 \u5b97\u7537\u60a3\u8005\u7684\u6bcd\u89aa",
#                     "gender": "F",
#                     "hospital_en": "Ruttonjee Hospital",
#                     "hospital_zh": "\u5f8b\u6566\u6cbb\u91ab\u9662",
#                     "onset_date": "2020-01-29",
#                     "source_url": "https://hk.news.appledaily.com/local/20200210/BCZLE5EYY4BPLHD4AYCOYSB22Y/?utm_campaign=hkad_social_hk.nextmedia&utm_medium=social&utm_source=telegram",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             },
#             {
#                 "node": {
#                     "age": "22",
#                     "case_no": "32",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_possibly_close_contact",
#                     "confirmation_date": "2020-02-09",
#                     "detail_en": "Cousin of patient 27",
#                     "detail_zh": "\u7b2c 27 \u5b97\u7537\u60a3\u8005\u7684\u8868\u5f1f",
#                     "gender": "M",
#                     "hospital_en": "Pamela Youde Nethersole Eastern Hospital",
#                     "hospital_zh": "\u6771\u5340\u5c24\u5fb7\u592b\u4eba\u90a3\u6253\u7d20\u91ab\u9662",
#                     "onset_date": "2020-01-28",
#                     "source_url": "https://hk.news.appledaily.com/local/20200210/BCZLE5EYY4BPLHD4AYCOYSB22Y/?utm_campaign=hkad_social_hk.nextmedia&utm_medium=social&utm_source=telegram",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             },
#             {
#                 "node": {
#                     "age": "50",
#                     "case_no": "33",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_possibly_close_contact",
#                     "confirmation_date": "2020-02-09",
#                     "detail_en": "Aunt of patient 27",
#                     "detail_zh": "\u7b2c 27 \u5b97\u7537\u60a3\u8005\u7684\u56db\u59e8",
#                     "gender": "F",
#                     "hospital_en": "Ruttonjee Hospital",
#                     "hospital_zh": "\u5f8b\u6566\u6cbb\u91ab\u9662",
#                     "onset_date": "2020-02-02",
#                     "source_url": "https://hk.news.appledaily.com/local/20200210/BCZLE5EYY4BPLHD4AYCOYSB22Y/?utm_campaign=hkad_social_hk.nextmedia&utm_medium=social&utm_source=telegram",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             },
#             {
#                 "node": {
#                     "age": "25",
#                     "case_no": "34",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_possibly_close_contact",
#                     "confirmation_date": "2020-02-09",
#                     "detail_en": "Cousin of patient 27",
#                     "detail_zh": "\u7b2c 27 \u5b97\u7537\u60a3\u8005\u7684\u8868\u59d0",
#                     "gender": "F",
#                     "hospital_en": "Pamela Youde Nethersole Eastern Hospital",
#                     "hospital_zh": "\u6771\u5340\u5c24\u5fb7\u592b\u4eba\u90a3\u6253\u7d20\u91ab\u9662",
#                     "onset_date": "2020-01-30",
#                     "source_url": "https://hk.news.appledaily.com/local/20200210/BCZLE5EYY4BPLHD4AYCOYSB22Y/?utm_campaign=hkad_social_hk.nextmedia&utm_medium=social&utm_source=telegram",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             },
#             {
#                 "node": {
#                     "age": "51",
#                     "case_no": "35",
#                     "citizenship_en": "Hong Kong",
#                     "citizenship_zh": "\u9999\u6e2f",
#                     "classification": "local_possibly_close_contact",
#                     "confirmation_date": "2020-02-09",
#                     "detail_en": "Aunt of patient 27",
#                     "detail_zh": "\u7b2c 27 \u5b97\u7537\u60a3\u8005\u7684\u4e09\u59e8",
#                     "gender": "F",
#                     "hospital_en": "Pamela Youde Nethersole Eastern Hospital",
#                     "hospital_zh": "\u6771\u5340\u5c24\u5fb7\u592b\u4eba\u90a3\u6253\u7d20\u91ab\u9662",
#                     "onset_date": "2020-02-05",
#                     "source_url": "https://hk.news.appledaily.com/local/20200210/BCZLE5EYY4BPLHD4AYCOYSB22Y/?utm_campaign=hkad_social_hk.nextmedia&utm_medium=social&utm_source=telegram",
#                     "status": "hospitalised",
#                     "type_en": "Confirmed",
#                     "type_zh": "\u78ba\u8a3a"
#                 }
#             }
#         ]
#     },
#     "allWarsLatestFiguresOverride": {
#         "edges": [
#             {
#                 "node": {
#                     "confirmed": "38",
#                     "date": "2020-02-10",
#                     "death": "",
#                     "discharged": "",
#                     "investigating": "",
#                     "remarks_en": "",
#                     "remarks_zh": "",
#                     "reported": "",
#                     "ruled_out": "",
#                     "time": ""
#                 }
#             }
#         ]
#     }
# }
#   death confirmed investigating reported
# 0     1        38           129     1231

# %%
with open(r'../data/STATS.pkl', 'wb') as f:
    pickle.dump(stats_df, f)

# %% [markdown]
# ## Hospitals Addresses

# %%
with open(r'../data/HOSPITALS.pkl', 'rb') as f:
    hospitals_df = pickle.load(f)

# %%
hospitals_df.head()
# Out:
#    id                                   address   latitude   longitude  \
# 0   0     Alice Ho Miu Ling Nethersole Hospital  22.458515  114.174944
# 1   1                   North District Hospital  22.496759  114.124606
# 2   2                     North Lantau Hospital  22.282335  113.939275
# 3   3                           Pok Oi Hospital  22.445444  114.041639
# 4   4  Pamela Youde Nethersole Eastern Hospital  22.270224  114.236770
#
#    category
# 0  Hospital
# 1  Hospital
# 2  Hospital
# 3  Hospital
# 4  Hospital

# %% [markdown]
# ## Addresses

# %%
from webscraper import fetch_highrisk

# %%
high_risk_df = fetch_highrisk()

# %%
with open(r'../data/HIGH_RISK.pkl', 'rb') as f:
    high_risk_df = pickle.load(f)

# %%
high_risk_df
# Out:
#                                        id sub_district_zh sub_district_en  \
# 0    12c65515-4747-5f77-ab29-f245927c8495              元朗       Yuen Long
# 1    231b10bc-0194-5da0-878d-9a062b23b7eb              葵涌      Kwai Chung
# 2    2cbe3b86-cc9e-5905-8616-8c50e5c6ac86              青衣        Tsing Yi
# 3    3c8a0f8d-5ebc-5348-8046-e54de8062c5c             鑽石山    Diamond Hill
# 4    ee2399e4-2cb3-5075-92e6-835cc8719edd              沙田         Sha Tin
# ..                                    ...             ...             ...
# 170  d56ff11f-70ed-578d-a60f-198600738946             秀茂坪    Sau Mau Ping
# 171  be65e274-5dea-5868-a1ed-c9998db9b888              境外      Outside HK
# 172  1b7ec0c5-0773-59e4-a3de-8e10d9f36aac              上水     Sheung Shui
# 173  69abfbab-30f6-5434-95df-8f5d7f3019b1              上水     Sheung Shui
# 174  e236743d-bb95-52bb-8ee3-fbf9a4eb2d89              境外      Outside HK
#
#     action_zh       action_en  \
# 0        家居檢疫  Home Confinees
# 1        家居檢疫  Home Confinees
# 2        家居檢疫  Home Confinees
# 3        家居檢疫  Home Confinees
# 4        家居檢疫  Home Confinees
# ..        ...             ...
# 170        求醫         Medical
# 171        逗留            Stay
# 172        離港       Departure
# 173        抵港         Arrival
# 174        逗留            Stay
#
#                                            location_en           location_zh  \
# 0                                Block 3, Sereno Verde                蝶翠峰 3座
# 1                         Block A, Kwai Chung Building               葵涌大廈 A座
# 2                             Block 1, Villa Esplanada                灝景灣 1座
# 3                      Pik Fung House, Fung Tak Estate                鳳德村碧鳳樓
# 4                   Kwong Ning Building, Shatin Centre              沙田中心廣寧大廈
# ..                                                 ...                   ...
# 170  Orthopedics and Traumatic Clinic, United Chris...  基督教聯合醫院矯形及創傷科（骨科）門診部
# 171                                              Macau                    澳門
# 172                                Lo Wu Control Point                 羅湖管制站
# 173                                Lo Wu Control Point                 羅湖管制站
# 174                                  Shunde, Guangdong                  廣東順德
#
#                                      remarks_en  remarks_zh  \
# 0
# 1
# 2
# 3
# 4
# ..                                          ...         ...
# 170
# 171
# 172
# 173
# 174  Sought medical treatment in a local clinic  曾於當地一家診所求醫
#
#                                           source_url_1  \
# 0    https://www.chp.gov.hk/files/pdf/list_of_build...
# 1    https://www.chp.gov.hk/files/pdf/list_of_build...
# 2    https://www.chp.gov.hk/files/pdf/list_of_build...
# 3    https://www.chp.gov.hk/files/pdf/list_of_build...
# 4    https://www.chp.gov.hk/files/pdf/list_of_build...
# ..                                                 ...
# 170  https://hk.news.appledaily.com/local/20200201/...
# 171  https://www.thestandnews.com/society/%E6%AD%A6...
# 172  https://news.rthk.hk/rthk/ch/component/k2/1506...
# 173  https://news.rthk.hk/rthk/ch/component/k2/1506...
# 174  https://www.thestandnews.com/society/%E6%AD%A6...
#
#                                           source_url_2 start_date   end_date  \
# 0    https://www.chp.gov.hk/files/pdf/list_of_build... 2020-02-06 2020-02-20
# 1    https://www.chp.gov.hk/files/pdf/list_of_build... 2020-02-04 2020-02-18
# 2    https://www.chp.gov.hk/files/pdf/list_of_build... 2020-02-04 2020-02-18
# 3    https://www.chp.gov.hk/files/pdf/list_of_build... 2020-02-02 2020-02-16
# 4    https://www.chp.gov.hk/files/pdf/list_of_build... 2020-01-31 2020-02-14
# ..                                                 ...        ...        ...
# 170                                                    2020-01-15 2020-01-15
# 171  https://www.scmp.com/news/hong-kong/health-env... 2020-01-10 2020-01-14
# 172  https://hk.news.appledaily.com/local/20200201/... 2020-01-10 2020-01-10
# 173  https://hk.news.appledaily.com/local/20200201/... 2020-01-10 2020-01-10
# 174  https://www.scmp.com/news/hong-kong/health-env... 2020-12-30 2020-01-07
#
#      type case_no case
# 0    self       -
# 1    self       -
# 2    self       -
# 3    self       -
# 4    self       -
# ..    ...     ...  ...
# 170  self      14   14
# 171  self      12   12
# 172  self      14   14
# 173  self      14   14
# 174  self      12   12
#
# [175 rows x 16 columns]

# %%
with open(r'../data/ADDRESS.pkl', 'rb') as f:
    address_df = pickle.load(f)

# %%
address_df = address_df.loc[
    0:0
]

# %%
address_df
# Out:
#                                      id sub_district_zh sub_district_en  \
# 0  5c0c68c7-f6a2-51f0-9fb8-943b360316fc              葵涌      Kwai Chung
#
#                                  location_en      location_zh longitude  \
# 0  Kwai Chung Building, 10-30 Shek Pui Stret  石貝街 10-30 號葵涌大廈   114.201
#
#   latitude
# 0   22.345

# %%
address_df.loc[0, 'longitude'] = 114.136282
address_df.loc[0, 'latitude'] = 22.364730

# %%
with open(r'../data/ADDRESS.pkl', 'wb') as f:
    pickle.dump(address_df, f)

# %%
high_risk_df.head(10)
# Out:
#                                      id sub_district_zh sub_district_en  \
# 0  f434cb97-b3c8-5884-9daa-53fbcb7ba418             鑽石山    Diamond Hill
# 1  0e65810a-5340-5cab-9df3-7d986c017325              沙田         Sha Tin
# 2  995f78dd-31e8-55cf-806a-364f7e8327ad             天水圍    Tin Shui Wai
# 3  d65d9703-5442-5ae6-a9cc-ce9ca2e9ffa9              屯門        Tuen Mun
# 4  139ef4e1-1688-5ccd-b960-6d1e7f003eac              藍田         Lam Tin
# 5  209f58c1-0b44-5748-b406-483d7138af49              上水     Sheung Shui
# 6  6fc9aecf-abcd-5eb9-a623-c964011051c4              粉嶺         Fanling
# 7  c0f5bc6a-82c8-5091-9e38-680d5d05299e              沙田         Sha Tin
# 8  e7a1b5c4-abec-5818-ac62-413f25b3fe9c              大圍         Tai Wai
# 9  cc3341f8-7e9a-5679-baf9-01ae2ae15f98             深水埗    Sham Shui Po
#
#   action_zh       action_en                                location_en  \
# 0      家居檢疫  Home Confinees            Pik Fung House, Fung Tak Estate
# 1      家居檢疫  Home Confinees         Kwong Ning Building, Shatin Centre
# 2      家居檢疫  Home Confinees  Block 5, Sherwood Court, Kingswood Villas
# 3      家居檢疫  Home Confinees           Tip Ling House, Butterfly Estate
# 4      家居檢疫  Home Confinees          Ping Shing House, Ping Tin Estate
# 5      家居檢疫  Home Confinees                         15 Po Sheung Tsuen
# 6      家居檢疫  Home Confinees                    Block 11, Dawning Views
# 7      家居檢疫  Home Confinees                    Block 5, Jubilee Garden
# 8      家居檢疫  Home Confinees             Tower 5, Phase 2 Festival City
# 9      家居檢疫  Home Confinees       Wing On Building, 206 Fuk Wah Street
#
#      location_zh remarks_en remarks_zh  \
# 0         鳳德村碧鳳樓
# 1       沙田中心廣寧大廈
# 2    嘉湖山莊賞湖居 5 座
# 3         蝴蝶邨蝶翎樓
# 4         平田邨平誠樓
# 5       莆上村 15 號
# 6       牽晴間 11 座
# 7       銀禧花園 5 座
# 8   大圍名城 2 期 5 座
# 9  福華街 206 號榮安大廈
#
#                                         source_url_1  \
# 0  https://www.chp.gov.hk/files/pdf/list_of_build...
# 1  https://www.chp.gov.hk/files/pdf/list_of_build...
# 2  https://www.chp.gov.hk/files/pdf/list_of_build...
# 3  https://www.chp.gov.hk/files/pdf/list_of_build...
# 4  https://www.chp.gov.hk/files/pdf/list_of_build...
# 5  https://www.chp.gov.hk/files/pdf/list_of_build...
# 6  https://www.chp.gov.hk/files/pdf/list_of_build...
# 7  https://www.chp.gov.hk/files/pdf/list_of_build...
# 8  https://www.chp.gov.hk/files/pdf/list_of_build...
# 9  https://www.chp.gov.hk/files/pdf/list_of_build...
#
#                                         source_url_2 start_date end_date  \
# 0  https://www.chp.gov.hk/files/pdf/list_of_build...       04/2     18/2
# 1  https://www.chp.gov.hk/files/pdf/list_of_build...       02/2     16/2
# 2  https://www.chp.gov.hk/files/pdf/list_of_build...       31/1     14/2
# 3  https://www.chp.gov.hk/files/pdf/list_of_build...       30/1     13/2
# 4  https://www.chp.gov.hk/files/pdf/list_of_build...       30/1     13/2
# 5  https://www.chp.gov.hk/files/pdf/list_of_build...       30/1     13/2
# 6  https://www.chp.gov.hk/files/pdf/list_of_build...       30/1     13/2
# 7  https://www.chp.gov.hk/files/pdf/list_of_build...       30/1     13/2
# 8  https://www.chp.gov.hk/files/pdf/list_of_build...       30/1     13/2
# 9  https://www.chp.gov.hk/files/pdf/list_of_build...       30/1     13/2
#
#    type case_no case
# 0  self       -
# 1  self       -
# 2  self       -
# 3  self       -
# 4  self       -
# 5  self       -
# 6  self       -
# 7  self       -
# 8  self       -
# 9  self       -

# %%
address_df = high_risk_df[['id', 'sub_district_zh', 'sub_district_en', 'location_en', 'location_zh']].copy()

# %%
address_df['longitude'] = None
address_df['latitude'] = None

# %%
from wuhan_functions import get_coordinates

# %%
with open(r'../data/old_format/ADDRESS.pkl', 'rb') as f:
    old_address_df = pickle.load(f)

# %%
for idx, row in address_df.iterrows():
    if old_address_df[old_address_df['address'] == row['location_en']].shape[0] == 1:
        address_df.at[idx, 'longitude'] = old_address_df[old_address_df['address'] == row['location_en']]['longitude'].values[0]
        address_df.at[idx, 'latitude'] = old_address_df[old_address_df['address'] == row['location_en']]['latitude'].values[0]

# %%
address_df.head()
# Out:
#                                      id sub_district_zh sub_district_en  \
# 0  5c0c68c7-f6a2-51f0-9fb8-943b360316fc              葵涌      Kwai Chung
# 1  f434cb97-b3c8-5884-9daa-53fbcb7ba418             鑽石山    Diamond Hill
# 2  0e65810a-5340-5cab-9df3-7d986c017325              沙田         Sha Tin
# 3  139ef4e1-1688-5ccd-b960-6d1e7f003eac             天水圍    Tin Shui Wai
# 4  209f58c1-0b44-5748-b406-483d7138af49              藍田         Lam Tin
#
#                                  location_en      location_zh longitude  \
# 0  Kwai Chung Building, 10-30 Shek Pui Stret  石貝街 10-30 號葵涌大廈   114.163
# 1            Pik Fung House, Fung Tak Estate           鳳德村碧鳳樓   114.201
# 2         Kwong Ning Building, Shatin Centre         沙田中心廣寧大廈    114.19
# 3  Block 5, Sherwood Court, Kingswood Villas      嘉湖山莊賞湖居 5 座       114
# 4          Ping Shing House, Ping Tin Estate           平田邨平誠樓   114.237
#
#   latitude
# 0  22.2793
# 1  22.3443
# 2   22.383
# 3  22.4521
# 4  22.3055

# %%
for idx, row in address_df[address_df['longitude'].isna()].iterrows():
    print(row['location_zh'])
    address_name = row['location_en'] + ', ' + row['sub_district_en']
    if 'high speed rail' in address_name.lower():
        latitude = 22.304080
        longitude = 114.166501
    elif '航空' in row['location_zh']:
        latitude = 22.308007
        longitude = 113.918803
    else:
        latitude, longitude = get_coordinates(address_name)
    address_df.at[idx, 'latitude'] = latitude
    address_df.at[idx, 'longitude'] = longitude
# Out:
# 清河村清照樓
# Getting the coordinates for new address: Ching Chiu House, Ching Ho Estate, Sheung Shui.
# 天慈村慈平樓
# Getting the coordinates for new address: Tsz Ping House, Tin Tsz Estate, Tin Shui Wai.
# 香港理工大學勵志堂
# Getting the coordinates for new address: Lizhi Hall, The Hong Kong Polytechnic University, Hung Hom.
# 天富苑榮富閣
# Getting the coordinates for new address: Wing Fu House, Tin Fu Court, Tin Shui Wai.
# 鴨脷洲邨利添樓
# Getting the coordinates for new address: Lei Tim House, Ap Lei Chau Estate, Ap Lei Chau.
# 大窩口邨富德樓
# Getting the coordinates for new address: Fu Tak House, Tai Wo Hau Estate, Kwai Chung.
# 港景峰 1 座
# Getting the coordinates for new address: Block 1, Victoria Towers, Jordan.
# 黃埔花園第 2 期 10 座
# Getting the coordinates for new address: Block 10, Cherry Mansions, Whampoa Garden (Site2), Hung Hom.
# 媽横路福順樓
# Getting the coordinates for new address: Fook Shun Building, 45-67 Ma Wang Road, Yuen Long.
# 嘉湖山莊麗湖居 4 座
# Getting the coordinates for new address: Block 4, Lynwood Court, Kingswood Villas (Phase 5), Tin Shui Wai.
# 李達三葉耀珍伉儷李本俊會議大樓
# Getting the coordinates for new address: Li Dak Sum Yip Yio Chin Kenneth Li Conference Lodge, Clear Water Bay.
# 佳景路 9 號浩明園
# Getting the coordinates for new address: Ho Ming Court, 9 Kai King Road, Tseung Kwan O.
# 楊屋道 100 號爵悅庭西爵
# Getting the coordinates for new address: Tower West, Chelsea Court, 90-114 Yeung Uk Road, Tsuen Wan.
# 宜安街 2-4 號致昌大厦
# Getting the coordinates for new address: Chi Cheong Building, 2-4 Yee On Street, Kwun Tong.
# 嘉湖山莊賞湖居 2 座
# Getting the coordinates for new address: Block 2, Sherwood Court, Kingswood Villas, Tin Shui Wai.
# 環宇海灣 8 座
# Getting the coordinates for new address: Block 8, City Point, Tsuen Wan.
# 香港大學賽馬會第三學生村宿舍 B 棟
# Getting the coordinates for new address: Hall B, Jockey Club Student Village III, The University of Hong Kong, Kennedy Town.
# 怡明邨怡茵樓
# Getting the coordinates for new address: Tai Po Tsai Village, Clear Water Bay Road, Tseung Kwan O.
# 竹園南邨麗園樓
# Getting the coordinates for new address: Lung Yat House,Lower Wong Tai Sin Estate, Wong Tai Sin.
# 佐敦道 18-24 號鴻運大廈
# Getting the coordinates for new address: Lucky House, 18-24 Jordan Road, Jordan.
# 利奧坊曉岸 1 座
# Getting the coordinates for new address: Tower 1, Eltanin Square Mile, Tai Kok Tsui.
# 窩打老道 3A 號
# Getting the coordinates for new address: 3A Waterloo Road, Yau Ma Tei.
# 香港中文大學昆棟樓
# Getting the coordinates for new address: Chan Kwan Tung Inter-university Hall, The Chinese University of Hong Kong, Sha Tin.
# 黃埔花園 2 期 10 座
# Getting the coordinates for new address: Block 10, Cherry Mansions, Whampoa Garden (Site2), Hung Hom.
# 寶馬山 8 座
# Getting the coordinates for new address: Block 8, Grand Palisades, Tai Po.
# 卑路戶街 1 號三匯大廈
# Getting the coordinates for new address: Sum Way Mansion , 1 Belchers Street, Shek Tong Tsui.
# 美景居 11 座
# Getting the coordinates for new address: Block 11, Goodview Court, Kam Tin.
# 港灣豪庭 6 座
# Getting the coordinates for new address: Block 6, Metro Harbour View, Tai Kok Tsui.
# 成業街 15-17 號成運工業大廈
# Getting the coordinates for new address: Sing Win Factory Building, 15-17 Shing Yip Street, Kwun Tong.
# 樂華北村勤華樓
# Getting the coordinates for new address: Kan Wah House, Lok Wah North Estate, Ngau Tau Kok.
# 順利邨利富樓 5 樓
# Getting the coordinates for new address: Lee Foo House , Shun Lee Estate, Kwun Tong.
# 渡船街文英樓前座
# Getting the coordinates for new address: Front Block, Man Ying Building, Ferry Street, Jordan.
# 香港中文大學昆棟樓
# Getting the coordinates for new address: Chan Kwan Tung Inter-university Hall, The Chinese University of Hong Kong, Fo Tan.
# 青山公路 8 號嶺南大學訪客公寓
# Getting the coordinates for new address: Visitors' Quarters, 8 Castle Peak Road, Lingnan University, Tuen Mun.
# 大圍名城 1 期 1 座
# Getting the coordinates for new address: Tower 1, Phase 1 Festival City, Tai Wai.
# 東亞銀行中心36樓
# Getting the coordinates for new address: 36th Floor, BEA Tower, Millennium City 5, Kwun Tong.
# 土瓜灣馬頭圍道183號
# Getting the coordinates for new address: 183 Ma Tau Wai Road, To Kwa Wan, To Kwa Wan.
# 浸信會醫院門診部
# Getting the coordinates for new address: Hong Kong Baptist Hospital Out-patient Clinic, Kowloon Tong.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 灝景灣
# Getting the coordinates for new address: Villa Esplanada, Tsing Yi.
# 九龍貿易中心
# Getting the coordinates for new address: Kowloon Commerce Centre, Kwai Chung.
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 黃埔花園第十一期1座
# Getting the coordinates for new address: Whampoa Garden Site 11 Block 1, Hung Hom.
# 康田苑裕康閣
# Getting the coordinates for new address: Yue Hong House, Hong Tin Court, Tseung Kwan O.
# 九龍灣德福花園卓健醫療診所
# Getting the coordinates for new address: Quality Healthcare Integrated Centre, Kowloon Bay, Kowloon Bay.
# 聯合醫院急症室
# Getting the coordinates for new address: United Christian Hospital Accident & Emergency Department, Sau Mau Ping.
# 將軍澳醫院急症室
# Getting the coordinates for new address: Tseung Kwan O Hospital Accident & Emergency Department, Tseung Kwan O.
# 半山壹號
# Getting the coordinates for new address: Celestial Heights, Ho Man Tin.
# 恆豐中心店舖號碼 LG8「Fresh Up」
# Getting the coordinates for new address: Fresh Up, Shop LG8, Prudential Centre, Jordan.
# 香港 W 酒店
# Getting the coordinates for new address: W Hotel Hong Kong, Yau Ma Tei.
# 香港麗思卡爾頓酒店
# Getting the coordinates for new address: The Ritz-Carlton Hong Kong, Yau Ma Tei.
# 香港 W 酒店
# Getting the coordinates for new address: W Hotel Hong Kong, Yau Ma Tei.
# 香港麗思卡爾頓酒店
# Getting the coordinates for new address: The Ritz-Carlton Hong Kong, Yau Ma Tei.
# 香港 W 酒店
# Getting the coordinates for new address: W Hotel Hong Kong, Yau Ma Tei.
# 香港麗思卡爾頓酒店
# Getting the coordinates for new address: The Ritz-Carlton Hong Kong, Yau Ma Tei.
# 東京
# Getting the coordinates for new address: Tokyo, Outside HK.
# 麥理浩夫人度假村
# Getting the coordinates for new address: Lady MacLehose Holiday Village, Sai Kung.
# 屯門醫院急症室
# Getting the coordinates for new address: Tuen Mun Hospital Accident & Emergency Departments, Tuen Mun.
# 聖十字架堂
# Getting the coordinates for new address: Holy Cross Church, Sai Wan Ho.
# 羅湖管制站
# Getting the coordinates for new address: Lo Wu Control Point, Sheung Shui.
# 北區醫院急症室
# Getting the coordinates for new address: North District Hospital Accident & Emergency Department, Sheung Shui.
# 鑽石公主號
# Getting the coordinates for new address: Diamond Princess cruise, Outside HK.
# 屯門醫院急症室
# Getting the coordinates for new address: Tuen Mun Hospital Accident & Emergency Departments, Tuen Mun.
# 長康邨康美樓
# Getting the coordinates for new address: Cheung Hong Estate Hong Mei House, Tsing Yi.
# 恆豐中心店舖號碼 LG8「Fresh Up」
# Getting the coordinates for new address: Fresh Up, Shop LG8, Prudential Centre, Jordan.
# 屯門醫院急症室
# Getting the coordinates for new address: Tuen Mun Hospital Accident & Emergency Departments, Tuen Mun.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 律敦治醫院急症室
# Getting the coordinates for new address: Ruttonjee Hospital Accident & Emergency Department, Wan Chai.
# 武漢
# Getting the coordinates for new address: Wu Han, Outside HK.
# 高鐵 G79
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 嘉賓大廈一間私家診所
# Getting the coordinates for new address: A clinic in Champion Building, Jordan.
# 尖沙咀皇悅酒店
# Getting the coordinates for new address: Empire Hotel Kowloon, Tsim Sha Tsui.
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 宿霧航空 5J111
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 國泰港龍航空 KA853
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 國泰港龍航空 KA853
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 深圳
# Getting the coordinates for new address: Shen Zhen, Outside HK.
# 羅湖管制站
# Getting the coordinates for new address: Lo Wu Control Point, Sheung Shui.
# 羅湖港鐵站
# Getting the coordinates for new address: Lo Wu Station, Sheung Shui.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 高鐵 G1013
# 高鐵 G6543
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 高鐵 G1013
# 高鐵 G6543
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 澳門
# Getting the coordinates for new address: Macau, Outside HK.
# 羅湖管制站
# Getting the coordinates for new address: Lo Wu Control Point, Sheung Shui.
# 羅湖管制站
# Getting the coordinates for new address: Lo Wu Control Point, Sheung Shui.
# 廣東順德
# Getting the coordinates for new address: Shunde, Guangdong, Outside HK.

# %%
with open(r'../data/ADDRESS.pkl', 'wb') as f:
    pickle.dump(address_df, f)

# %% [markdown]
# ## Casese

# %%
with open(r'../data/CASES.pkl', 'rb') as f:
    cases_df = pickle.load(f)

# %%
from webscraper import fetch_cases

cases_df = fetch_cases()

# %%
cases_df
# Out:
#    case_no  onset_date confirmation_date gender age  hospital_zh  \
# 8       25                    2020-02-07      M  58         北區醫院
# 7       26                    2020-02-07      M  42      威爾斯親王醫院
# 11      22                    2020-02-06      F  55        瑪嘉烈醫院
# 10      23                    2020-02-06      F  63  東區尤德夫人那打素醫院
# 9       24                    2020-02-06      F  65      威爾斯親王醫院
# 15      19                    2020-02-05      F  28        瑪嘉烈醫院
# 12      21                    2020-02-05      M  56        瑪嘉烈醫院
# 13      20                    2020-02-05      F  56        瑪嘉烈醫院
# 16      18                    2020-02-05      M  25        瑪嘉烈醫院
# 17      17                    2020-02-04      M  60        瑪嘉烈醫院
# 18      16                    2020-02-03      F  64        瑪嘉烈醫院
# 19      15                    2020-02-02      F  72        瑪嘉烈醫院
# 20      14                    2020-02-01      M  80        瑪嘉烈醫院
# 21      13                    2020-01-31      M  39        瑪嘉烈醫院
# 22      12                    2020-01-30      M  75        瑪嘉烈醫院
# 23      11                    2020-01-30      F  37        瑪嘉烈醫院
# 24      10                    2020-01-29      M  72        瑪嘉烈醫院
# 0        9                    2020-01-29      F  73        瑪嘉烈醫院
# 1        8                    2020-01-26      M  64        瑪嘉烈醫院
# 3        6                    2020-01-26      M  47        瑪嘉烈醫院
# 2        7                    2020-01-26      F  68        瑪嘉烈醫院
# 6        3                    2020-01-24      F  62        瑪嘉烈醫院
# 5        4                    2020-01-24      F  62        瑪嘉烈醫院
# 4        5                    2020-01-24      M  63        瑪嘉烈醫院
# 14       2                    2020-01-23      M  56        瑪嘉烈醫院
# 25       1  2020-01-21        2020-01-23      M  39        瑪嘉烈醫院
#
#                                  hospital_en        status type_zh    type_en  \
# 8                    North District Hospital  hospitalised      確診  Confirmed
# 7                   Prince of Wales Hospital  hospitalised      確診  Confirmed
# 11                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 10  Pamela Youde Nethersole Eastern Hospital  hospitalised      確診  Confirmed
# 9                   Prince of Wales Hospital       serious      確診  Confirmed
# 15                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 12                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 13                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 16                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 17                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 18                Princess Margaret Hospital      critical      確診  Confirmed
# 19                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 20                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 21                Princess Margaret Hospital      deceased      確診  Confirmed
# 22                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 23                Princess Margaret Hospital  hospitalised      確診  Confirmed
# 24                Princess Margaret Hospital       serious      確診  Confirmed
# 0                 Princess Margaret Hospital  hospitalised      確診  Confirmed
# 1                 Princess Margaret Hospital  hospitalised      確診  Confirmed
# 3                 Princess Margaret Hospital  hospitalised      確診  Confirmed
# 2                 Princess Margaret Hospital      critical      確診  Confirmed
# 6                 Princess Margaret Hospital  hospitalised      確診  Confirmed
# 5                 Princess Margaret Hospital  hospitalised      確診  Confirmed
# 4                 Princess Margaret Hospital  hospitalised      確診  Confirmed
# 14                Princess Margaret Hospital       serious      確診  Confirmed
# 25                Princess Margaret Hospital  hospitalised      確診  Confirmed
#
#    citizenship_zh citizenship_en  \
# 8              香港      Hong Kong
# 7              香港      Hong Kong
# 11             香港      Hong Kong
# 10             香港      Hong Kong
# 9              香港      Hong Kong
# 15             香港      Hong Kong
# 12             香港      Hong Kong
# 13             香港      Hong Kong
# 16             香港      Hong Kong
# 17             香港      Hong Kong
# 18             香港      Hong Kong
# 19             香港      Hong Kong
# 20             香港      Hong Kong
# 21             香港      Hong Kong
# 22             香港      Hong Kong
# 23             香港      Hong Kong
# 24             武漢          Wuhan
# 0              武漢          Wuhan
# 1              武漢          Wuhan
# 3              香港      Hong Kong
# 2              香港      Hong Kong
# 6              武漢          Wuhan
# 5              武漢          Wuhan
# 4              武漢          Wuhan
# 14             香港      Hong Kong
# 25             武漢          Wuhan
#
#                                             detail_zh  \
# 8   患者在珠海及香港北區坑頭雍翠苑居住，並於珠海及澳門工作，2 月 4 日出現發燒和咳嗽。他 2...
# 7   患者居於沙田御龍山第10座。2月 3 日出現發燒和咳嗽，2 月 6 日到威爾斯親王醫院求醫，...
# 11  該名女病人是第 21 宗確診個案的太太。  早前在東莞工作， 1月 17 日回港， 1 月 ...
# 10  患者1月26日開始咳嗽和疲倦，曾向中醫求診；2 月 5 日向私家醫生求診，再到東區醫院急症室...
# 9   患者為一名獨居於沙田碩門邨瑞碩樓、有長期病患的65歲女子，本身有甲狀腺機能低下症及高血壓。1...
# 15            該名女病人是第 17 宗確診個案的女兒。 2 月 4 日發燒，到聯合醫院隔離。
# 12  男患者在青衣灝景灣一座居住，在深圳工作，長期往返兩地。患者曾在 1 月 21 日到過深圳，在...
# 13            該名女病人是第 17 宗確診個案的妻子。 2 月 4 日發燒，到聯合醫院隔離。
# 16  男患者住在土瓜灣馬頭圍道183號， 1 月 14 日到浸會醫院求醫，確診感染甲型流感，獲處方...
# 17  男患者已退休，住在藍田康田苑裕康閣。1月22日起發燒及疲倦，1月30日有氣喘，病人分別於1月...
# 18  女患者居於半山壹號，佐敦恆豐中心開店。 1 月 23 日咳嗽，在佐敦嘉賓大廈診所求醫；1 月...
# 19  該名女病人是第 13 確診個案的母親。 1 月 31 日第 13 宗確診個案入院接受隔離治療...
# 20  男患者居於葵涌邨綠葵樓。1 月 10 日經羅湖口岸到內地逗留數小時， 17 日乘飛機到東京，...
# 21  有長期病患的男患者居於黃埔花園 11 期 1 座。1 月 21 日曾乘搭高鐵到武漢探親，1 ...
# 22  該名 75 歲男子居於青衣長康邨康美樓，於 1 月 22 日咳嗽及呼吸困難，1 月 24 日...
# 23  該名女病人是第 9 及 10 確診個案的女兒，或成為全港首宗「人傳人」個案。該患者居於香港油...
# 24  該名男病人 1 月 22 日乘坐飛機到港，隨即入住過 W 酒店，數天後又轉住四季酒店，但最後...
# 0   該名女病人 1 月 22 日乘坐飛機到港，隨即入住過 W 酒店，數天後又轉住四季酒店，於該酒...
# 1   64 歲男長期病患病人居於武漢市，1 月 19 日與妻子 （no.3） 乘搭高鐵經深圳北到達...
# 3   曾訛稱任職「會計師」，實際上是武漢武昌白沙洲市場的收銀員，曾因被狗咬而於 1 月 23 日到...
# 2   該名 68 歲女子居於粉嶺，本月曾到武漢，曾因不適而到深圳醫院求醫，測試結果對甲型流感呈陽性...
# 6   1 月 19 日乘搭高鐵由武漢到港，入住屯門倚嶺南庭，自 1 月 20 日起出現病徵，23 ...
# 5   62 歲女病人與丈夫 1 月 24 日從武漢來港探望居住在馬鞍山銀湖天峰的女兒，二人與女兒到...
# 4   63 歲男病人與妻子 1 月 24 日從武漢來港探望居住在馬鞍山銀湖天峰的女兒，到醫院求醫，...
# 14  1 月 19 日由武漢乘坐航班前往深圳，再經羅湖乘東鐵轉馬鐵返馬鞍山，因發燒到威院求診後入住...
# 25  1 月 21 日搭高鐵來港，於西九龍站發現發燒，即時送院，同行 4 名親人入住尖沙咀皇悅酒店...
#
#                                             detail_en  \
# 8   The patient has both Zhuhai and Hong Kong (Ser...
# 7   The patient resides in Block 10, The Palazzo, ...
# 11  The patient is the spouse of case no. 21. She ...
# 10  The patient developed cough and fatigue on Jan...
# 9   The patient is a 65-year-old female who lives ...
# 15  The female patient is the daughter of case no....
# 12  The male patient lives in Tsing Yi and works i...
# 13  The female patient is the spouse of case no. 1...
# 16  The male patient lives at 183 Ma Tau Wai Road....
# 17  The male patient has retired and lives in Yue ...
# 18  The patient lives in Celestial Heights and own...
# 19  The female patient is the mother of case no.13...
# 20  The patient lives in Luk Kwai House, Kwai Chun...
# 21  The male patient with chronic illness lived in...
# 22  The 75 year-old patient lives in Hong Mei Hous...
# 23  \nThe female patient is the daughter of cases ...
# 24  The male patient arrived in Hong Kong by plane...
# 0   The female patient arrived in Hong Kong by pla...
# 1   The 64 year-old male patient from Wuhan has ch...
# 3   The patient claimed to have worked as an accou...
# 2   The 68 year-old female patient lives in Fan Li...
# 6   The female patient took a high-speed rail trai...
# 5   The 62 year-old female patient came from Wuhan...
# 4   The 63 year-old male patient came from Wuhan w...
# 14  The patient flew from Wuhan to Shenzhen and th...
# 25  The patient travelled to Hong Kong via high-sp...
#
#                   classification  \
# 8                       imported
# 7                       imported
# 11  local_possibly_close_contact
# 10          local_unknown_source
# 9           local_unknown_source
# 15           local_close_contact
# 12                local_possibly
# 13           local_close_contact
# 16          local_unknown_source
# 17          local_unknown_source
# 18          local_unknown_source
# 19        imported_close_contact
# 20                local_possibly
# 21                      imported
# 22                local_possibly
# 23        imported_close_contact
# 24                      imported
# 0                       imported
# 1                       imported
# 3                       imported
# 2                       imported
# 6                       imported
# 5                       imported
# 4                       imported
# 14                      imported
# 25                      imported
#
#                                            source_url
# 8   https://hk.on.cc/hk/bkn/cnt/news/20200207/bkn-...
# 7   https://news.rthk.hk/rthk/ch/component/k2/1507...
# 11  https://news.rthk.hk/rthk/ch/component/k2/1507...
# 10  https://hk.news.appledaily.com/local/20200206/...
# 9   https://hk.news.appledaily.com/local/20200206/...
# 15  https://news.rthk.hk/rthk/ch/component/k2/1506...
# 12  https://www.info.gov.hk/gia/general/202002/05/...
# 13  https://news.rthk.hk/rthk/ch/component/k2/1506...
# 16  https://news.rthk.hk/rthk/ch/component/k2/1506...
# 17  https://www.thestandnews.com/society/%E6%AD%A6...
# 18  https://www.hk01.com/%E7%A4%BE%E6%9C%83%E6%96%...
# 19  https://www.thestandnews.com/politics/%E6%AD%A...
# 20  https://news.rthk.hk/rthk/ch/component/k2/1506...
# 21  http://hd.stheadline.com/news/realtime/hk/1691...
# 22  https://www.thestandnews.com/society/%E6%AD%A6...
# 23  https://www.hk01.com/%E7%A4%BE%E6%9C%83%E6%96%...
# 24  https://news.rthk.hk/rthk/ch/component/k2/1505...
# 0   https://news.rthk.hk/rthk/ch/component/k2/1505...
# 1   https://www.thestandnews.com/politics/%E6%AD%A...
# 3   https://hk.appledaily.com/local/20200127/LDSLV...
# 2   https://hk.on.cc/hk/bkn/cnt/news/20200126/bkn-...
# 6   https://news.rthk.hk/rthk/ch/component/k2/1504...
# 5   https://www.thestandnews.com/politics/%E6%AD%A...
# 4   https://www.thestandnews.com/politics/%E6%AD%A...
# 14  https://hd.stheadline.com/news/realtime/hk/168...
# 25  https://www.thestandnews.com/society/%E6%AD%A6...

# %%
with open(r'../data/CASES.pkl', 'wb') as f:
    pickle.dump(cases_df, f)

# %% [markdown]
# ## Awaiting

# %%
with open(r'../data/AWAITING.pkl', 'rb') as f:
    awaiting_df = pickle.load(f)

# %%
from webscraper import fetch_awaiting_time

awaiting_df = fetch_awaiting_time()

# %%
with open(r'../data/AWAITING.pkl', 'wb') as f:
    pickle.dump(awaiting_df, f)

# %%
awaiting_df
# Out:
#         name_zh                                   name_en hospCode  \
# 0          明愛醫院                    Caritas Medical Centre      CMC
# 1          廣華醫院                        Kwong Wah Hospital      KWH
# 2        北大嶼山醫院                     North Lantau Hospital      NLT
# 3   東區尤德夫人那打素醫院  Pamela Youde Nethersole Eastern Hospital      PYN
# 4        伊利沙伯醫院                  Queen Elizabeth Hospital      QEH
# 5          瑪麗醫院                       Queen Mary Hospital      QMH
# 6          長洲醫院                          St John Hospital      SJH
# 7         將軍澳醫院                    Tseung Kwan O Hospital      TKO
# 8          仁濟醫院                         Yan Chai Hospital      YCH
# 9   雅麗氏何妙齡那打素醫院     Alice Ho Miu Ling Nethersole Hospital      AHN
# 10        瑪嘉烈醫院                Princess Margaret Hospital      PMH
# 11         博愛醫院                           Pok Oi Hospital      POH
# 12      威爾斯親王醫院                  Prince of Wales Hospital      PWH
# 13         屯門醫院                         Tuen Mun Hospital      TMH
# 14        天水圍醫院                     Tin Shui Wai Hospital      TSH
# 15      基督教聯合醫院                 United Christian Hospital      UCH
# 16         北區醫院                   North District Hospital      NDH
# 17        律敦治醫院                        Ruttonjee Hospital       RH
#
#           hospTimeEn topWait district_zh        district_en sub_district_zh  \
# 0   8/2/2020 11:30am     < 1         深水埗       Sham Shui Po             深水埗
# 1   8/2/2020 11:30am     < 1         油尖旺      Yau Tsim Mong              旺角
# 2   8/2/2020 11:30am     < 1          離島            Islands              東涌
# 3   8/2/2020 11:30am     < 1          東區            Eastern              柴灣
# 4   8/2/2020 11:30am     < 1         油尖旺      Yau Tsim Mong             油麻地
# 5   8/2/2020 11:30am     < 1         中西區  Central & Western             薄扶林
# 6   8/2/2020 11:30am     < 1          離島            Islands              長洲
# 7   8/2/2020 11:30am     < 1          西貢           Sai Kung             將軍澳
# 8   8/2/2020 11:30am     < 1          荃灣          Tsuen Wan              荃灣
# 9   8/2/2020 11:30am     > 1          大埔             Tai Po              大埔
# 10  8/2/2020 11:30am     > 1          葵青         Kwai Tsing              葵涌
# 11  8/2/2020 11:30am     > 1          元朗          Yuen Long              元朗
# 12  8/2/2020 11:30am     > 1          沙田            Sha Tin              沙田
# 13  8/2/2020 11:30am     > 1          屯門           Tuen Mun              屯門
# 14  8/2/2020 11:30am     > 1          元朗          Yuen Long             天水圍
# 15  8/2/2020 11:30am     > 1          觀塘          Kwun Tong              觀塘
# 16  8/2/2020 11:30am     > 2          北區              North              上水
# 17  8/2/2020 11:30am     > 5          灣仔           Wan Chai              灣仔
#
#    sub_district_en  topWait_value
# 0     Sham Shui Po              0
# 1         Mong Kok              0
# 2       Tung Chung              0
# 3         Chai Wan              0
# 4       Yau Ma Tei              0
# 5       Pok Fu Lam              0
# 6      Cheung Chau              0
# 7    Tseung Kwan O              0
# 8        Tsuen Wan              0
# 9           Tai Po              1
# 10      Kwai Chung              1
# 11       Yuen Long              1
# 12         Sha Tin              1
# 13        Tuen Mun              1
# 14    Tin Shui Wai              1
# 15       Kwun Tong              1
# 16     Sheung Shui              2
# 17        Wan Chai              5

# %%
awaiting_df['topWait_value'].max()
# Out:
# numpy.int64

# %%
{i: f'> {i} hr' for i in np.arange(0, awaiting_df['topWait_value'].max() + 1)}[awaiting_df['topWait_value'].max()]
# Out:
# '> 5 hr'
