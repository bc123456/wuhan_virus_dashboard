# %%
import pickle
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %% [markdown]
# ## Stats

# %%
with open(r'../data/STATS.pkl', 'rb') as f:
    stats_df = pickle.load(f)

# %%
stats_df
# Out:
#   Death Confirmed Investigating Reported
# 0     1        26           158     1158

# %% [markdown]
# ## Address

# %%
with open(r'../data/ADDRESS.pkl', 'rb') as f:
    address_df = pickle.load(f)

# %%
address_profile = ProfileReport(address_df, title='Pandas Profiling Report', html={'style':{'full_width':True}})
address_profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %% [markdown]
# ## HIGH_RISK

# %%
with open(r'../data/HIGH_RISK.pkl', 'rb') as f:
	high_risk_df = pickle.load(f)

# %%
high_risk_df_profile = ProfileReport(high_risk_df, title='Pandas Profiling Report', html={'style':{'full_width':True}})
high_risk_df_profile
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %% [markdown]
# ## Cases

# %%
with open(r'../data/CASES.pkl', 'rb') as f:
	cases_df = pickle.load(f)

# %%
cases_df_profile = ProfileReport(cases_df, title='Pandas Profiling Report', html={'style':{'full_width':True}})
cases_df_profile
# Out:
# /Users/brianchanmy/git_repository/wuhan_virus_dashboard/.venv/lib/python3.6/site-packages/pandas_profiling/model/correlations.py:35: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(phi2corr / min((kcorr - 1.0), (rcorr - 1.0)))
# /Users/brianchanmy/git_repository/wuhan_virus_dashboard/.venv/lib/python3.6/site-packages/pandas_profiling/model/correlations.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(phi2corr / min((kcorr - 1.0), (rcorr - 1.0)))
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
cases_df
# Out:
#    case_no  onset_date confirmation_date gender age  hospital_zh  \
# 8       25                    2020-02-07      M  58         北區醫院
# 7       26                    2020-02-07      M  42      威爾斯親王醫院
# 11      22                    2020-02-06      F  55        瑪嘉烈醫院
# 10      23                    2020-02-06      F  63  東區尤德夫人那打素醫院
# 9       24                    2020-02-06      F  65      威爾斯親王醫院
# 15      19                    2020-02-05      F  28        瑪嘉烈醫院
# 12      21                    2020-02-05      M  56        瑪嘉烈醫院
# 13      20                    2020-02-05      F  56        瑪嘉烈醫院
# 16      18                    2020-02-05      M  25        瑪嘉烈醫院
# 17      17                    2020-02-04      M  60        瑪嘉烈醫院
# 18      16                    2020-02-03      F  64        瑪嘉烈醫院
# 19      15                    2020-02-02      F  72        瑪嘉烈醫院
# 20      14                    2020-02-01      M  80        瑪嘉烈醫院
# ...
