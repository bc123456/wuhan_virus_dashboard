# %%
import pandas as pd
import pickle
import numpy as np
import sys
import requests
import json
sys.path.insert(1, '../src')

# %% [markdown]
# ## Basic Statistics

# %%
with open(r'../data/STATS.pkl', 'rb') as f:
    stats_df = pickle.load(f)

# %%
from webscraper import fetch_stat
stats_df = fetch_stat()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-3fb96b816c5f> in <module>
#       1 from webscraper import fetch_stat
# ----> 2 stats_df = fetch_stat()
#
# ~\Documents\git_repository\wuhan_virus_dashboard\src\webscraper.py in fetch_stat()
#     102     data = json.loads(page.content)
#     103 #     print(json.dumps(data['result']['data'], indent=4, sort_keys=True))
# --> 104     stats_yesterday = data['result']['data']['allBotWarsLatestFigures']['edges'][0]
#     105     stats_live = data['result']['data']['allWarsLatestFiguresOverride']['edges'][0]
#     106
#
# KeyError: 'data'

# %%
stats_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-179869ad10fe> in <module>
# ----> 1 stats_df
#
# NameError: name 'stats_df' is not defined

# %%
# source_json = r'https://wars.vote4.hk/page-data/index/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/disruption/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/ae-waiting-time/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/shops/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/news/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/poster-gallery/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/about-us/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/wars-tips/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/high-risk/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/cases/page-data.json'
# source_json = r'https://wars.vote4.hk/page-data/world/page-data.json'
source_json = r'https://wars.vote4.hk/page-data/en/page-data.json'

# %%
from wuhan_functions import calculate_stats

# %%
calculate_stats(cases_df)
# Out:
#    death  confirmed  discharged  hospitalised
# 0      4       1013         434           554

# %%
with open(r'../data/STATS.pkl', 'wb') as f:
    pickle.dump(stats_df, f)

# %% [markdown]
# ## Hospitals Addresses

# %%
with open(r'../data/HOSPITALS.pkl', 'rb') as f:
    hospitals_df = pickle.load(f)

# %%
hospitals_df.head()
# Out:
#    id                                   address   latitude   longitude  \
# 0   0     Alice Ho Miu Ling Nethersole Hospital  22.458515  114.174944
# 1   1                   North District Hospital  22.496759  114.124606
# 2   2                     North Lantau Hospital  22.282335  113.939275
# 3   3                           Pok Oi Hospital  22.445444  114.041639
# 4   4  Pamela Youde Nethersole Eastern Hospital  22.270224  114.236770
#
#    category
# 0  Hospital
# 1  Hospital
# 2  Hospital
# 3  Hospital
# 4  Hospital

# %% [markdown]
# ## Addresses

# %%
from webscraper import fetch_highrisk

# %%
high_risk_df = fetch_highrisk()

# %%
high_risk_df
# Out:
#                                         id sub_district_zh sub_district_en  \
# 0     0115d69a-dc7e-5928-ae54-36ac35812ce7               -               -
# 1     11353905-edbf-5820-89b4-fd222f612e3c               -               -
# 2     caa1dc3f-3ce8-5750-a23a-24a184cf1226               -               -
# 3     b27fb25d-eaf2-5131-88e7-328aaf55cb2b               -               -
# 4     b5687dfa-fd1b-5471-b084-451d329db29e               -               -
# ...                                    ...             ...             ...
# 2811  cbb578bc-ba4e-5141-b28a-4e3e831a7e6b              葵涌      Kwai Chung
# 2812  c8f381b8-e179-5854-b727-439cad876e42              屯門        Tuen Mun
# 2813  dedfdcfa-1b2a-5aff-bfb2-4617f3fcf557              大圍         Tai Wai
# 2814  54bf17cd-9ea6-549f-9e38-1cbe15232d3a             半山區      Mid-levels
# 2815  a4aa1f55-7699-5029-ad37-427abcb38d9c              屯門        Tuen Mun
#
#      action_zh  action_en                       location_en  \
# 0           交通  Transport  Virgin Atlantic VS206 (seat 59G)
# 1           交通  Transport  Virgin Atlantic VS206 (seat 55G)
# 2           交通  Transport   Cathay Pacific CX252 (seat 60H)
# 3           交通  Transport   Cathay Pacific CX252 (seat 15K)
# 4           交通  Transport    Qatar Airways QR818 (seat 21A)
# ...        ...        ...                               ...
# 2811        住宿  Residence   Fu Tai House, Tai Wo Hau Estate
# 2812        住宿  Residence           Block 8, Seaview Garden
# 2813        住宿  Residence            Block 2, Carado Garden
# 2814        住宿  Residence           Block 3, Garden Terrace
# 2815        住宿  Residence                 Tower 11, Avignon
#
#                 location_zh           remarks_en remarks_zh  \
# 0     維珍航空 VS206 ( 座位 59G )  London to Hong Kong      由倫敦抵港
# 1     維珍航空 VS206 ( 座位 55G )  London to Hong Kong      由倫敦抵港
# 2       國泰航空 CX252（座位 60H ）  London to Hong Kong      由倫敦抵港
# 3       國泰航空 CX252（座位 15K ）  London to Hong Kong      由倫敦抵港
# 4       卡塔爾航空 QR818（座位 21A）    Doha to Hong Kong      由多哈抵港
# ...                     ...                  ...        ...
# 2811                大窩口邨富泰樓
# 2812                 海景花園8座
# 2813                雲疊花園 2座
# 2814                 花園台 3座
# 2815                 星堤 11座
#
#                                            source_url_1  \
# 0     https://www.chp.gov.hk/files/pdf/flights_train...
# 1     https://www.chp.gov.hk/files/pdf/flights_train...
# 2     https://www.chp.gov.hk/files/pdf/flights_train...
# 3     https://www.chp.gov.hk/files/pdf/flights_train...
# 4     https://www.chp.gov.hk/files/pdf/flights_train...
# ...                                                 ...
# 2811  https://www.chp.gov.hk/files/pdf/flights_train...
# 2812  https://www.chp.gov.hk/files/pdf/flights_train...
# 2813  https://www.chp.gov.hk/files/pdf/building_list...
# 2814  https://www.chp.gov.hk/files/pdf/building_list...
# 2815  https://www.chp.gov.hk/files/pdf/flights_train...
#
#                                            source_url_2 start_date   end_date  \
# 0     https://www.chp.gov.hk/files/pdf/flights_train... 2020-04-11 2020-04-12
# 1     https://www.chp.gov.hk/files/pdf/flights_train... 2020-04-11 2020-04-12
# 2     https://www.chp.gov.hk/files/pdf/flights_train... 2020-04-09 2020-04-10
# 3     https://www.chp.gov.hk/files/pdf/flights_train... 2020-04-09 2020-04-10
# 4     https://www.chp.gov.hk/files/pdf/flights_train... 2020-04-10 2020-04-10
# ...                                                 ...        ...        ...
# 2811  https://www.chp.gov.hk/files/pdf/flights_train...        NaT        NaT
# 2812  https://www.chp.gov.hk/files/pdf/flights_train...        NaT        NaT
# 2813  https://www.chp.gov.hk/files/pdf/building_list...        NaT        NaT
# 2814  https://www.chp.gov.hk/files/pdf/building_list...        NaT        NaT
# 2815  https://www.chp.gov.hk/files/pdf/flights_train...        NaT        NaT
#
#              lat          lng  type case_no  case
# 0                              self    1006  1006
# 1                              self    1010  1010
# 2                              self     994   994
# 3                              self     995   995
# 4                              self     999   999
# ...          ...          ...   ...     ...   ...
# 2811  22.3659664  114.1226154  self    1004  1004
# 2812  22.3777723  113.9842903  self    1005  1005
# 2813   22.368507   114.177542  self    1007  1007
# 2814  22.2756382  114.1541769  self    1009  1009
# 2815   22.375214   113.999066  self    1013  1013
#
# [2816 rows x 18 columns]

# %%
with open(r'../data/HIGH_RISK.pkl', 'rb') as f:
    high_risk_df = pickle.load(f)

# %%
high_risk_df
# Out:
#                                        id sub_district_zh sub_district_en  \
# 0    2e5b6380-8a1b-5db3-92ac-ea3cb6f12cf7            堅尼地城    Kennedy Town
# 1    88d2e5d4-6391-5d14-a271-9bb73b134dad             深水埗    Sham Shui Po
# 2    5d231903-3e65-5070-8c87-a1dd4c14bc38              啟德         Kai Tak
# 3    18014346-f70c-5c1e-b1a6-aa2b6d656cb1              東涌      Tung Chung
# 4    a4e092fd-37c2-561c-9690-7be987cf48da              荃灣       Tsuen Wan
# ..                                    ...             ...             ...
# 420  8be5b35b-d8f7-5e44-b4c8-469b81c882c4              北角     North Point
# 421  ccc0947d-6b1d-5992-9a0d-5b0bf1171ebe              元朗       Yuen Long
# 422  2178e07e-6442-5505-9b30-13b8b8a5e1c7              石澳          Shek O
# 423  cb950c3b-6e22-533c-9f61-c0d2d6dca324              北角     North Point
# 424  5c61ece8-47e8-5d8e-9b4d-0ca837070d02              北角     North Point
#
#     action_zh       action_en  \
# 0        家居檢疫  Home Confinees
# 1        家居檢疫  Home Confinees
# 2        家居檢疫  Home Confinees
# 3        家居檢疫  Home Confinees
# 4        家居檢疫  Home Confinees
# ..        ...             ...
# 420        逗留            Stay
# 421        住宿       Residence
# 422        住宿       Residence
# 423        住宿       Residence
# 424        逗留            Stay
#
#                                            location_en  \
# 0    Block E, Minor Staff Quarters, The University ...
# 1                Chiu Nan Building, 212 Tai Nan Street
# 2                 Sheung Ching House, Kai Ching Estate
# 3                            Block 5, Seaview Crescent
# 4                   Tin Po Building, 74 Hau Tei Square
# ..                                                 ...
# 420  Fook Wai Ching She, Maylun Apartments, 23 Shu ...
# 421                                Tower 3, Grand Yoho
# 422                         Red Hill Peninsula Phase 1
# 423                                Majestic Apartments
# 424                         Cheung Yeung Street Market
#
#                  location_zh  \
# 0    蒲飛路 13-21 號香港大學職工宿舍 E 座
# 1               大南街 212 號朝南樓
# 2                     啟晴邨賞晴樓
# 3                   海堤灣畔 5 座
# 4               鱟地坊 74 號天保大樓
# ..                       ...
# 420         書局街 23 號美輪大廈福慧精舍
# 421            GRAND YOHO第三座
# 422                  紅山半島第一期
# 423                     麗宮大廈
# 424                    春秧街街市
#
#                                             remarks_en    remarks_zh  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...           ...
# 420  The patient goes to preaching hall for several...  每朝都會到佛堂逗留數分鐘
# 421
# 422
# 423
# 424
#
#                                           source_url_1 source_url_2  \
# 0    https://hk.appledaily.com/local/20200215/MDN3H...
# 1    https://hk.appledaily.com/local/20200215/MDN3H...
# 2    https://hk.appledaily.com/local/20200215/MDN3H...
# 3    https://hk.appledaily.com/local/20200215/MDN3H...
# 4    https://hk.appledaily.com/local/20200215/MDN3H...
# ..                                                 ...          ...
# 420  https://news.rthk.hk/rthk/ch/component/k2/1510...
# 421  https://news.rthk.hk/rthk/ch/component/k2/1510...
# 422  https://news.rthk.hk/rthk/ch/component/k2/1510...
# 423  https://news.rthk.hk/rthk/ch/component/k2/1510...
# 424  https://news.rthk.hk/rthk/ch/component/k2/1510...
#
#     start_date   end_date         lat         lng            type case_no case
# 0   2020-02-12 2020-02-26    22.28098  114.130239  home_confinees       -
# 1   2020-02-12 2020-02-26   22.327606  114.163024  home_confinees       -
# 2   2020-02-12 2020-02-26   22.333568  114.203167  home_confinees       -
# 3   2020-02-12 2020-02-26   22.291778  113.943094  home_confinees       -
# 4   2020-02-11 2020-02-25   22.371106  114.114993  home_confinees       -
# ..         ...        ...         ...         ...             ...     ...  ...
# 420 2020-02-22 2020-01-07     22.2909    114.2003            self      74   74
# 421 2020-02-22 2020-01-07     22.4456     114.037            self      75   75
# 422 2020-02-22 2020-01-07     22.2307    114.2276            self      76   76
# 423 2020-02-22 2020-01-07   22.290574  114.196108            self      77   77
# 424 2020-02-22 2020-01-07  22.2911185  114.195006            self      77   77
#
# [425 rows x 18 columns]

# %%
from wuhan_functions import get_coordinates

# %%
with open(r'../data/old_format/ADDRESS.pkl', 'rb') as f:
    old_address_df = pickle.load(f)

# %%
for idx, row in address_df.iterrows():
    if old_address_df[old_address_df['address'] == row['location_en']].shape[0] == 1:
        address_df.at[idx, 'longitude'] = old_address_df[old_address_df['address'] == row['location_en']]['longitude'].values[0]
        address_df.at[idx, 'latitude'] = old_address_df[old_address_df['address'] == row['location_en']]['latitude'].values[0]

# %%
address_df.head()
# Out:
#                                      id sub_district_zh sub_district_en  \
# 0  5c0c68c7-f6a2-51f0-9fb8-943b360316fc              葵涌      Kwai Chung
# 1  f434cb97-b3c8-5884-9daa-53fbcb7ba418             鑽石山    Diamond Hill
# 2  0e65810a-5340-5cab-9df3-7d986c017325              沙田         Sha Tin
# 3  139ef4e1-1688-5ccd-b960-6d1e7f003eac             天水圍    Tin Shui Wai
# 4  209f58c1-0b44-5748-b406-483d7138af49              藍田         Lam Tin
#
#                                  location_en      location_zh longitude  \
# 0  Kwai Chung Building, 10-30 Shek Pui Stret  石貝街 10-30 號葵涌大廈   114.163
# 1            Pik Fung House, Fung Tak Estate           鳳德村碧鳳樓   114.201
# 2         Kwong Ning Building, Shatin Centre         沙田中心廣寧大廈    114.19
# 3  Block 5, Sherwood Court, Kingswood Villas      嘉湖山莊賞湖居 5 座       114
# 4          Ping Shing House, Ping Tin Estate           平田邨平誠樓   114.237
#
#   latitude
# 0  22.2793
# 1  22.3443
# 2   22.383
# 3  22.4521
# 4  22.3055

# %%
for idx, row in address_df[address_df['longitude'].isna()].iterrows():
    print(row['location_zh'])
    address_name = row['location_en'] + ', ' + row['sub_district_en']
    if 'high speed rail' in address_name.lower():
        latitude = 22.304080
        longitude = 114.166501
    elif '航空' in row['location_zh']:
        latitude = 22.308007
        longitude = 113.918803
    else:
        latitude, longitude = get_coordinates(address_name)
    address_df.at[idx, 'latitude'] = latitude
    address_df.at[idx, 'longitude'] = longitude
# Out:
# 清河村清照樓
# Getting the coordinates for new address: Ching Chiu House, Ching Ho Estate, Sheung Shui.
# 天慈村慈平樓
# Getting the coordinates for new address: Tsz Ping House, Tin Tsz Estate, Tin Shui Wai.
# 香港理工大學勵志堂
# Getting the coordinates for new address: Lizhi Hall, The Hong Kong Polytechnic University, Hung Hom.
# 天富苑榮富閣
# Getting the coordinates for new address: Wing Fu House, Tin Fu Court, Tin Shui Wai.
# 鴨脷洲邨利添樓
# Getting the coordinates for new address: Lei Tim House, Ap Lei Chau Estate, Ap Lei Chau.
# 大窩口邨富德樓
# Getting the coordinates for new address: Fu Tak House, Tai Wo Hau Estate, Kwai Chung.
# 港景峰 1 座
# Getting the coordinates for new address: Block 1, Victoria Towers, Jordan.
# 黃埔花園第 2 期 10 座
# Getting the coordinates for new address: Block 10, Cherry Mansions, Whampoa Garden (Site2), Hung Hom.
# 媽横路福順樓
# Getting the coordinates for new address: Fook Shun Building, 45-67 Ma Wang Road, Yuen Long.
# 嘉湖山莊麗湖居 4 座
# Getting the coordinates for new address: Block 4, Lynwood Court, Kingswood Villas (Phase 5), Tin Shui Wai.
# 李達三葉耀珍伉儷李本俊會議大樓
# Getting the coordinates for new address: Li Dak Sum Yip Yio Chin Kenneth Li Conference Lodge, Clear Water Bay.
# 佳景路 9 號浩明園
# Getting the coordinates for new address: Ho Ming Court, 9 Kai King Road, Tseung Kwan O.
# 楊屋道 100 號爵悅庭西爵
# Getting the coordinates for new address: Tower West, Chelsea Court, 90-114 Yeung Uk Road, Tsuen Wan.
# 宜安街 2-4 號致昌大厦
# Getting the coordinates for new address: Chi Cheong Building, 2-4 Yee On Street, Kwun Tong.
# 嘉湖山莊賞湖居 2 座
# Getting the coordinates for new address: Block 2, Sherwood Court, Kingswood Villas, Tin Shui Wai.
# 環宇海灣 8 座
# Getting the coordinates for new address: Block 8, City Point, Tsuen Wan.
# 香港大學賽馬會第三學生村宿舍 B 棟
# Getting the coordinates for new address: Hall B, Jockey Club Student Village III, The University of Hong Kong, Kennedy Town.
# 怡明邨怡茵樓
# Getting the coordinates for new address: Tai Po Tsai Village, Clear Water Bay Road, Tseung Kwan O.
# 竹園南邨麗園樓
# Getting the coordinates for new address: Lung Yat House,Lower Wong Tai Sin Estate, Wong Tai Sin.
# 佐敦道 18-24 號鴻運大廈
# Getting the coordinates for new address: Lucky House, 18-24 Jordan Road, Jordan.
# 利奧坊曉岸 1 座
# Getting the coordinates for new address: Tower 1, Eltanin Square Mile, Tai Kok Tsui.
# 窩打老道 3A 號
# Getting the coordinates for new address: 3A Waterloo Road, Yau Ma Tei.
# 香港中文大學昆棟樓
# Getting the coordinates for new address: Chan Kwan Tung Inter-university Hall, The Chinese University of Hong Kong, Sha Tin.
# 黃埔花園 2 期 10 座
# Getting the coordinates for new address: Block 10, Cherry Mansions, Whampoa Garden (Site2), Hung Hom.
# 寶馬山 8 座
# Getting the coordinates for new address: Block 8, Grand Palisades, Tai Po.
# 卑路戶街 1 號三匯大廈
# Getting the coordinates for new address: Sum Way Mansion , 1 Belchers Street, Shek Tong Tsui.
# 美景居 11 座
# Getting the coordinates for new address: Block 11, Goodview Court, Kam Tin.
# 港灣豪庭 6 座
# Getting the coordinates for new address: Block 6, Metro Harbour View, Tai Kok Tsui.
# 成業街 15-17 號成運工業大廈
# Getting the coordinates for new address: Sing Win Factory Building, 15-17 Shing Yip Street, Kwun Tong.
# 樂華北村勤華樓
# Getting the coordinates for new address: Kan Wah House, Lok Wah North Estate, Ngau Tau Kok.
# 順利邨利富樓 5 樓
# Getting the coordinates for new address: Lee Foo House , Shun Lee Estate, Kwun Tong.
# 渡船街文英樓前座
# Getting the coordinates for new address: Front Block, Man Ying Building, Ferry Street, Jordan.
# 香港中文大學昆棟樓
# Getting the coordinates for new address: Chan Kwan Tung Inter-university Hall, The Chinese University of Hong Kong, Fo Tan.
# 青山公路 8 號嶺南大學訪客公寓
# Getting the coordinates for new address: Visitors' Quarters, 8 Castle Peak Road, Lingnan University, Tuen Mun.
# 大圍名城 1 期 1 座
# Getting the coordinates for new address: Tower 1, Phase 1 Festival City, Tai Wai.
# 東亞銀行中心36樓
# Getting the coordinates for new address: 36th Floor, BEA Tower, Millennium City 5, Kwun Tong.
# 土瓜灣馬頭圍道183號
# Getting the coordinates for new address: 183 Ma Tau Wai Road, To Kwa Wan, To Kwa Wan.
# 浸信會醫院門診部
# Getting the coordinates for new address: Hong Kong Baptist Hospital Out-patient Clinic, Kowloon Tong.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 灝景灣
# Getting the coordinates for new address: Villa Esplanada, Tsing Yi.
# 九龍貿易中心
# Getting the coordinates for new address: Kowloon Commerce Centre, Kwai Chung.
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 黃埔花園第十一期1座
# Getting the coordinates for new address: Whampoa Garden Site 11 Block 1, Hung Hom.
# 康田苑裕康閣
# Getting the coordinates for new address: Yue Hong House, Hong Tin Court, Tseung Kwan O.
# 九龍灣德福花園卓健醫療診所
# Getting the coordinates for new address: Quality Healthcare Integrated Centre, Kowloon Bay, Kowloon Bay.
# 聯合醫院急症室
# Getting the coordinates for new address: United Christian Hospital Accident & Emergency Department, Sau Mau Ping.
# 將軍澳醫院急症室
# Getting the coordinates for new address: Tseung Kwan O Hospital Accident & Emergency Department, Tseung Kwan O.
# 半山壹號
# Getting the coordinates for new address: Celestial Heights, Ho Man Tin.
# 恆豐中心店舖號碼 LG8「Fresh Up」
# Getting the coordinates for new address: Fresh Up, Shop LG8, Prudential Centre, Jordan.
# 香港 W 酒店
# Getting the coordinates for new address: W Hotel Hong Kong, Yau Ma Tei.
# 香港麗思卡爾頓酒店
# Getting the coordinates for new address: The Ritz-Carlton Hong Kong, Yau Ma Tei.
# 香港 W 酒店
# Getting the coordinates for new address: W Hotel Hong Kong, Yau Ma Tei.
# 香港麗思卡爾頓酒店
# Getting the coordinates for new address: The Ritz-Carlton Hong Kong, Yau Ma Tei.
# 香港 W 酒店
# Getting the coordinates for new address: W Hotel Hong Kong, Yau Ma Tei.
# 香港麗思卡爾頓酒店
# Getting the coordinates for new address: The Ritz-Carlton Hong Kong, Yau Ma Tei.
# 東京
# Getting the coordinates for new address: Tokyo, Outside HK.
# 麥理浩夫人度假村
# Getting the coordinates for new address: Lady MacLehose Holiday Village, Sai Kung.
# 屯門醫院急症室
# Getting the coordinates for new address: Tuen Mun Hospital Accident & Emergency Departments, Tuen Mun.
# 聖十字架堂
# Getting the coordinates for new address: Holy Cross Church, Sai Wan Ho.
# 羅湖管制站
# Getting the coordinates for new address: Lo Wu Control Point, Sheung Shui.
# 北區醫院急症室
# Getting the coordinates for new address: North District Hospital Accident & Emergency Department, Sheung Shui.
# 鑽石公主號
# Getting the coordinates for new address: Diamond Princess cruise, Outside HK.
# 屯門醫院急症室
# Getting the coordinates for new address: Tuen Mun Hospital Accident & Emergency Departments, Tuen Mun.
# 長康邨康美樓
# Getting the coordinates for new address: Cheung Hong Estate Hong Mei House, Tsing Yi.
# 恆豐中心店舖號碼 LG8「Fresh Up」
# Getting the coordinates for new address: Fresh Up, Shop LG8, Prudential Centre, Jordan.
# 屯門醫院急症室
# Getting the coordinates for new address: Tuen Mun Hospital Accident & Emergency Departments, Tuen Mun.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 律敦治醫院急症室
# Getting the coordinates for new address: Ruttonjee Hospital Accident & Emergency Department, Wan Chai.
# 武漢
# Getting the coordinates for new address: Wu Han, Outside HK.
# 高鐵 G79
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 嘉賓大廈一間私家診所
# Getting the coordinates for new address: A clinic in Champion Building, Jordan.
# 尖沙咀皇悅酒店
# Getting the coordinates for new address: Empire Hotel Kowloon, Tsim Sha Tsui.
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 宿霧航空 5J111
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 國泰港龍航空 KA853
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 國泰港龍航空 KA853
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 深圳
# Getting the coordinates for new address: Shen Zhen, Outside HK.
# 羅湖管制站
# Getting the coordinates for new address: Lo Wu Control Point, Sheung Shui.
# 羅湖港鐵站
# Getting the coordinates for new address: Lo Wu Station, Sheung Shui.
# 威爾斯親王醫院急症室
# Getting the coordinates for new address: Prince of Wales Hospital Accident & Emergency Department, Sha Tin.
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 高鐵 G1013
# 高鐵 G6543
# 西九龍高鐵站
# Getting the coordinates for new address: Hong Kong West Kowloon Station, Jordan.
# 高鐵 G1013
# 高鐵 G6543
# 香港國際機場
# Getting the coordinates for new address: Hong Kong International Airport, Lantau Island.
# 澳門
# Getting the coordinates for new address: Macau, Outside HK.
# 羅湖管制站
# Getting the coordinates for new address: Lo Wu Control Point, Sheung Shui.
# 羅湖管制站
# Getting the coordinates for new address: Lo Wu Control Point, Sheung Shui.
# 廣東順德
# Getting the coordinates for new address: Shunde, Guangdong, Outside HK.

# %%
with open(r'../data/ADDRESS.pkl', 'wb') as f:
    pickle.dump(address_df, f)

# %% [markdown]
# ## Casese

# %%
with open(r'../data/CASES.pkl', 'rb') as f:
    cases_df = pickle.load(f)

# %%
from webscraper import fetch_cases

cases_df = fetch_cases()

# %%
cases_df
# Out:
#       case_no  onset_date confirmation_date gender age  hospital_zh  \
# 1012     1013        none        2020-04-14      M  22         屯門醫院
# 1011     1012        none        2020-04-14      M  16      基督教聯合醫院
# 1010     1011        none        2020-04-14      M  53         瑪麗醫院
# 1009     1010  2020-03-25        2020-04-13      M  51        瑪嘉烈醫院
# 1008     1009        none        2020-04-13      F   1  東區尤德夫人那打素醫院
# ...       ...         ...               ...    ...  ..          ...
# 4           5  2020-01-23        2020-01-24      M  63        瑪嘉烈醫院
# 3           4  2020-01-23        2020-01-24      F  62        瑪嘉烈醫院
# 2           3  2020-01-20        2020-01-24      F  62        瑪嘉烈醫院
# 1           2  2020-01-18        2020-01-23      M  56        瑪嘉烈醫院
# 0           1  2020-01-21        2020-01-23      M  39        瑪嘉烈醫院
#
#                                    hospital_en        status status_zh  \
# 1012                         Tuen Mun Hospital  hospitalised       住院中
# 1011                 United Christian Hospital  hospitalised       住院中
# 1010                       Queen Mary Hospital  hospitalised       住院中
# 1009                Princess Margaret Hospital  hospitalised       住院中
# 1008  Pamela Youde Nethersole Eastern Hospital  hospitalised       住院中
# ...                                        ...           ...       ...
# 4                   Princess Margaret Hospital    discharged        出院
# 3                   Princess Margaret Hospital    discharged        出院
# 2                   Princess Margaret Hospital    discharged        出院
# 1                   Princess Margaret Hospital    discharged        出院
# 0                   Princess Margaret Hospital    discharged        出院
#
#          status_en type_zh    type_en citizenship_zh citizenship_en  \
# 1012  Hospitalised      確診  Confirmed             屯門       Tuen Mun
# 1011  Hospitalised      確診  Confirmed             不明      Uncertain
# 1010  Hospitalised      確診  Confirmed             不明      Uncertain
# 1009  Hospitalised      確診  Confirmed             不明      Uncertain
# 1008  Hospitalised      確診  Confirmed            半山區     Mid-levels
# ...            ...     ...        ...            ...            ...
# 4       Discharged      確診  Confirmed             武漢          Wuhan
# 3       Discharged      確診  Confirmed             武漢          Wuhan
# 2       Discharged      確診  Confirmed             武漢          Wuhan
# 1       Discharged      確診  Confirmed            馬鞍山     Ma On Shan
# 0       Discharged      確診  Confirmed             武漢          Wuhan
#
#                                               detail_zh  \
# 1012  患者為英國留學生，沒有病徵。3 月 24 日抵港，由於當時未加強檢疫及病毒檢測安排故沒有留深...
# 1011              患者是美國留學生，4月13日從美國返港，並沒有任何病徵。由亞洲博覽館送院。
# 1010                患者3月11日至4月13日到過美國，並沒有任何病徵，由亞洲博覽館送院。
# 1009  患者居於英國，4 月 12 日返港，由亞洲博覽館送院，3 月 25 日在英國已出現發燒、咳嗽...
# 1008  患者為 14 個月大孩童，與家人於 2 月 1 日至 4 月 7 日曾到英國，沒有病徵，其家...
# ...                                                 ...
# 4     男患者與妻子於 1 月 24 日從武漢來港探望居住在馬鞍山銀湖天峰的女兒，到醫院求醫，夫婦須...
# 3     62 歲女患者與丈夫於 1 月 24 日從武漢來港探望居住在馬鞍山銀湖天峰的女兒。二人與女兒...
# 2     1 月 19 日乘搭高鐵由武漢到港，入住屯門倚嶺南庭。自 1 月 20 日起出現病徵，23 ...
# 1     1 月 10 日獨自前往武漢，1 月 19 日由武漢乘坐航班前往深圳，再經羅湖乘東鐵轉馬鐵返...
# 0     1 月 21 日搭高鐵來港，同日出現發燒及鼻塞，於西九龍站被發現發燒，即時送院。同行 4 名...
#
#                                               detail_en  classification  \
# 1012  The patient studies abroad in the UK and has n...  local_possibly
# 1011  The patient studies abroad in the US and retur...        imported
# 1010  The patient was in the US between March 11 and...        imported
# 1009  The patient lives in the UK and returned to Ho...        imported
# 1008  The patient is a 14-month-old infant and was i...        imported
# ...                                                 ...             ...
# 4     The 63 year-old male patient came from Wuhan w...        imported
# 3     The 62 year-old female patient came from Wuhan...        imported
# 2     The female patient took a high-speed rail trai...        imported
# 1     The patient travelled to Wuhan on Jan 10. He f...        imported
# 0     The patient travelled to Hong Kong via high-sp...        imported
#
#      classification_zh classification_en  \
# 1012            可能本地個案    Possibly local
# 1011              輸入個案          Imported
# 1010              輸入個案          Imported
# 1009              輸入個案          Imported
# 1008              輸入個案          Imported
# ...                ...               ...
# 4                 輸入個案          Imported
# 3                 輸入個案          Imported
# 2                 輸入個案          Imported
# 1                 輸入個案          Imported
# 0                 輸入個案          Imported
#
#                                              source_url
# 1012
# 1011
# 1010
# 1009  https://www.info.gov.hk/gia/general/202004/13/...
# 1008  https://www.info.gov.hk/gia/general/202004/13/...
# ...                                                 ...
# 4     https://www.thestandnews.com/politics/%E6%AD%A...
# 3     https://www.thestandnews.com/politics/%E6%AD%A...
# 2     https://news.rthk.hk/rthk/ch/component/k2/1504...
# 1     https://hd.stheadline.com/news/realtime/hk/168...
# 0     https://www.thestandnews.com/society/%E6%AD%A6...
#
# [1013 rows x 20 columns]

# %%
cases_df['type_zh'].value_counts()
# Out:
# 確診    1012
# 疑似       1
# Name: type_zh, dtype: int64

# %%
cases_df['status_en'].value_counts()
# Out:
# Hospitalised    554
# Discharged      434
# Critical         13
# Serious           8
# Deceased          4
# Name: status_en, dtype: int64

# %%
cases_df.shape
# Out:
# (1013, 20)

# %%
with open(r'../data/CASES.pkl', 'wb') as f:
    pickle.dump(cases_df, f)

# %% [markdown]
# ## Awaiting

# %%
with open(r'../data/AWAITING.pkl', 'rb') as f:
    awaiting_df = pickle.load(f)

# %%
from webscraper import fetch_awaiting_time

awaiting_df = fetch_awaiting_time()

# %%
with open(r'../data/AWAITING.pkl', 'wb') as f:
    pickle.dump(awaiting_df, f)

# %%
awaiting_df
# Out:
#         name_zh                                   name_en hospCode  \
# 0          明愛醫院                    Caritas Medical Centre      CMC
# 1          廣華醫院                        Kwong Wah Hospital      KWH
# 2        北大嶼山醫院                     North Lantau Hospital      NLT
# 3   東區尤德夫人那打素醫院  Pamela Youde Nethersole Eastern Hospital      PYN
# 4        伊利沙伯醫院                  Queen Elizabeth Hospital      QEH
# 5          瑪麗醫院                       Queen Mary Hospital      QMH
# 6          長洲醫院                          St John Hospital      SJH
# 7         將軍澳醫院                    Tseung Kwan O Hospital      TKO
# 8          仁濟醫院                         Yan Chai Hospital      YCH
# 9   雅麗氏何妙齡那打素醫院     Alice Ho Miu Ling Nethersole Hospital      AHN
# 10        瑪嘉烈醫院                Princess Margaret Hospital      PMH
# 11         博愛醫院                           Pok Oi Hospital      POH
# 12      威爾斯親王醫院                  Prince of Wales Hospital      PWH
# 13         屯門醫院                         Tuen Mun Hospital      TMH
# 14        天水圍醫院                     Tin Shui Wai Hospital      TSH
# 15      基督教聯合醫院                 United Christian Hospital      UCH
# 16         北區醫院                   North District Hospital      NDH
# 17        律敦治醫院                        Ruttonjee Hospital       RH
#
#           hospTimeEn topWait district_zh        district_en sub_district_zh  \
# 0   8/2/2020 11:30am     < 1         深水埗       Sham Shui Po             深水埗
# 1   8/2/2020 11:30am     < 1         油尖旺      Yau Tsim Mong              旺角
# 2   8/2/2020 11:30am     < 1          離島            Islands              東涌
# 3   8/2/2020 11:30am     < 1          東區            Eastern              柴灣
# 4   8/2/2020 11:30am     < 1         油尖旺      Yau Tsim Mong             油麻地
# 5   8/2/2020 11:30am     < 1         中西區  Central & Western             薄扶林
# 6   8/2/2020 11:30am     < 1          離島            Islands              長洲
# 7   8/2/2020 11:30am     < 1          西貢           Sai Kung             將軍澳
# 8   8/2/2020 11:30am     < 1          荃灣          Tsuen Wan              荃灣
# 9   8/2/2020 11:30am     > 1          大埔             Tai Po              大埔
# 10  8/2/2020 11:30am     > 1          葵青         Kwai Tsing              葵涌
# 11  8/2/2020 11:30am     > 1          元朗          Yuen Long              元朗
# 12  8/2/2020 11:30am     > 1          沙田            Sha Tin              沙田
# 13  8/2/2020 11:30am     > 1          屯門           Tuen Mun              屯門
# 14  8/2/2020 11:30am     > 1          元朗          Yuen Long             天水圍
# 15  8/2/2020 11:30am     > 1          觀塘          Kwun Tong              觀塘
# 16  8/2/2020 11:30am     > 2          北區              North              上水
# 17  8/2/2020 11:30am     > 5          灣仔           Wan Chai              灣仔
#
#    sub_district_en  topWait_value
# 0     Sham Shui Po              0
# 1         Mong Kok              0
# 2       Tung Chung              0
# 3         Chai Wan              0
# 4       Yau Ma Tei              0
# 5       Pok Fu Lam              0
# 6      Cheung Chau              0
# 7    Tseung Kwan O              0
# 8        Tsuen Wan              0
# 9           Tai Po              1
# 10      Kwai Chung              1
# 11       Yuen Long              1
# 12         Sha Tin              1
# 13        Tuen Mun              1
# 14    Tin Shui Wai              1
# 15       Kwun Tong              1
# 16     Sheung Shui              2
# 17        Wan Chai              5

# %%
awaiting_df['topWait_value'].max()
# Out:
# numpy.int64

# %%
{i: f'> {i} hr' for i in np.arange(0, awaiting_df['topWait_value'].max() + 1)}[awaiting_df['topWait_value'].max()]
# Out:
# '> 5 hr'
